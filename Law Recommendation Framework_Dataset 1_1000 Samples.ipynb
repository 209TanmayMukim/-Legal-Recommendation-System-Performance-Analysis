# %% [markdown]
# # Importing Labraries

# %%
import pandas as pd
import numpy as np
from transformers import BertTokenizer, BertModel
import torch
from gensim.models import Word2Vec
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import datetime
import seaborn as sns
import matplotlib.pyplot as Plot
import pickle
from transformers import BertTokenizer, BertForNextSentencePrediction, AdamW
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, TensorDataset, random_split
from torch.nn import functional as F
from transformers import AlbertTokenizer, AlbertModel
from transformers import DebertaTokenizer, DebertaModel

# %%
Data = pd.read_csv('database.csv')
Data
# Out:
#        case_id    docket_id       issues_id            vote_id date_decision  \
# 0     1946-001  1946-001-01  1946-001-01-01  1946-001-01-01-01    11/18/1946
# 1     1946-002  1946-002-01  1946-002-01-01  1946-002-01-01-01    11/18/1946
# 2     1946-003  1946-003-01  1946-003-01-01  1946-003-01-01-01    11/18/1946
# 3     1946-004  1946-004-01  1946-004-01-01  1946-004-01-01-01    11/25/1946
# 4     1946-005  1946-005-01  1946-005-01-01  1946-005-01-01-01    11/25/1946
# ...        ...          ...             ...                ...           ...
# 8732  2015-075  2015-075-01  2015-075-01-01  2015-075-01-01-01     6/27/2016
# 8733  2015-076  2015-076-01  2015-076-01-01  2015-076-01-01-01      6/9/2016
# 8734  2015-077  2015-077-01  2015-077-01-01  2015-077-01-01-01     5/31/2016
# 8735  2015-078  2015-078-01  2015-078-01-01  2015-078-01-01-01     5/31/2016
# 8736  2015-079  2015-079-01  2015-079-01-01  2015-079-01-01-01     5/16/2016
#
#       decision_type  us_citation   court_citation       led_citation  \
# 0                 1   329 U.S. 1      67 S. Ct. 6        91 L. Ed. 3
# 1                 1  329 U.S. 14     67 S. Ct. 13       91 L. Ed. 12
# 2                 1  329 U.S. 29      67 S. Ct. 1       91 L. Ed. 22
# 3                 7  329 U.S. 40    67 S. Ct. 167       91 L. Ed. 29
# 4                 1  329 U.S. 64    67 S. Ct. 154       91 L. Ed. 44
# ...             ...          ...              ...                ...
# 8732              1          NaN              NaN                NaN
# 8733              1          NaN              NaN  195 L. Ed. 2d 161
# 8734              2          NaN  136 S. Ct. 1818   195 L. Ed. 2d 99
# 8735              2          NaN  136 S. Ct. 1802   195 L. Ed. 2d 92
# 8736              2          NaN  136 S. Ct. 1603  194 L. Ed. 2d 701
#
#             lexis_citation  ...  authority_decision_two  law_type  \
# 0     1946 U.S. LEXIS 1724  ...                     NaN       6.0
# 1     1946 U.S. LEXIS 1725  ...                     NaN       6.0
# 2     1946 U.S. LEXIS 3037  ...                     NaN       2.0
# 3     1946 U.S. LEXIS 1696  ...                     NaN       6.0
# 4     1946 U.S. LEXIS 2997  ...                     NaN       NaN
# ...                    ...  ...                     ...       ...
# 8732  2016 U.S. LEXIS 4062  ...                     NaN       6.0
# 8733  2016 U.S. LEXIS 3772  ...                     NaN       9.0
# 8734  2016 U.S. LEXIS 3487  ...                     7.0       2.0
# 8735  2016 U.S. LEXIS 3488  ...                     3.0       9.0
# 8736  2016 U.S. LEXIS 3051  ...                     NaN       6.0
#
#      law_supplement                       law_minor_supplement  \
# 0             600.0                               35 U.S.C. 33
# 1             600.0                              18 U.S.C. 398
# 2             207.0                                        NaN
# 3             600.0                               49 Stat. 801
# 4               NaN                                        NaN
# ...             ...                                        ...
# 8732          600.0                 honest services wire fraud
# 8733          900.0                                        NaN
# 8734          230.0                                        NaN
# 8735          900.0                                        NaN
# 8736          600.0  antiterrorism and effective death penalty
#
#      majority_opinion_writer majority_opinion_assigner split_vote  \
# 0                         78                      78.0          1
# 1                         81                      87.0          1
# 2                         84                      78.0          1
# 3                         87                      87.0          1
# 4                         78                      87.0          1
# ...                      ...                       ...        ...
# 8732                     111                     111.0          1
# 8733                     113                     111.0          1
# 8734                     NaN                     111.0          1
# 8735                     NaN                     111.0          1
# 8736                     NaN                     111.0          1
#
#       majority_votes  minority_votes  Unnamed: 53
# 0                  8               1          NaN
# 1                  6               3          NaN
# 2                  5               4          NaN
# 3                  5               3          NaN
# 4                  6               3          NaN
# ...              ...             ...          ...
# 8732               8               0          NaN
# 8733               6               2          NaN
# 8734               6               2          NaN
# 8735               8               0          NaN
# 8736               6               2          NaN
#
# [8737 rows x 54 columns]

# %%
# Printing The Data Columns
print(Data.columns)
# Out:
# Index(['case_id', 'docket_id', 'issues_id', 'vote_id', 'date_decision',
#        'decision_type', 'us_citation', 'court_citation', 'led_citation',
#        'lexis_citation', 'term', 'court', 'chief_justice', 'docket',
#        'case_name', 'date_argument', 'date_reargument', 'petitioner',
#        'petitioner_state', 'respondent', 'respondent_state', 'jurisdiction',
#        'administrative_action', 'administrative_action_state',
#        'district_court', 'case_origin', 'case_origin_state', 'case_source',
#        'case_source_state', 'lower_court_disagreement', 'cert_reason',
#        'lower_court_disposition', 'lower_disposition_direction',
#        'declaration_unconstitutionality', 'case_disposition',
#        'disposition_unusual', 'party_winning', 'precedent_alteration',
#        'vote_unclear', 'issue', 'issue_area', 'decision_direction',
#        'decision_direction_dissent', 'authority_decision_one',
#        'authority_decision_two', 'law_type', 'law_supplement',
#        'law_minor_supplement', 'majority_opinion_writer',
#        'majority_opinion_assigner', 'split_vote', 'majority_votes',
#        'minority_votes', 'Unnamed: 53'],
#       dtype='object')

# %%
Data['case_name'] = Data['case_name'].str.replace('@', ' ')

# %% [markdown]
# Creating Term Frequency - Inverse Document Frequency

# %%
TFIDFML = TfidfVectorizer()
TFIDFML.fit(Data.case_name)
# Creating TF-IDF Dicitonary
Dictionary = dict(zip(TFIDFML.get_feature_names(), list(TFIDFML.idf_)))
# Defining Feature Name
TFIDFfeature = TFIDFML.get_feature_names()
for term, idf_value in Dictionary.items(): # Printing The Dictonary
    print(f'Term: {term}, IDF Value: {idf_value}')
print(TFIDFML.fit)
print(TFIDFfeature)
# Out:
# Term: 011, IDF Value: 9.382289428951436
# Term: 10, IDF Value: 9.382289428951436
# Term: 100, IDF Value: 8.97682432084327
# Term: 1000, IDF Value: 9.382289428951436
# Term: 1001, IDF Value: 9.382289428951436
# Term: 1029, IDF Value: 9.382289428951436
# Term: 103, IDF Value: 9.382289428951436
# Term: 104, IDF Value: 9.382289428951436
# Term: 107, IDF Value: 9.382289428951436
# Term: 11, IDF Value: 8.68914224839149
# Term: 112, IDF Value: 9.382289428951436
# Term: 114, IDF Value: 9.382289428951436
# Term: 1182, IDF Value: 9.382289428951436
# Term: 12, IDF Value: 8.97682432084327
# Term: 1212, IDF Value: 9.382289428951436
# Term: 1229, IDF Value: 9.382289428951436
# Term: 125, IDF Value: 9.382289428951436
# Term: 1263, IDF Value: 9.382289428951436
# Term: 1264, IDF Value: 9.382289428951436
# Term: 128, IDF Value: 9.382289428951436
# Term: 1285, IDF Value: 9.382289428951436
# Term: 1287, IDF Value: 9.382289428951436
# Term: 1291, IDF Value: 9.382289428951436
# Term: 13, IDF Value: 9.382289428951436
# Term: 1309, IDF Value: 9.382289428951436
# Term: 1315, IDF Value: 9.382289428951436
# Term: 134, IDF Value: 9.382289428951436
# Term: 14, IDF Value: 9.382289428951436
# Term: 1416, IDF Value: 9.382289428951436
# Term: 1424, IDF Value: 9.382289428951436
# Term: 144, IDF Value: 9.382289428951436
# Term: 149, IDF Value: 9.382289428951436
# Term: 15, IDF Value: 9.382289428951436
# Term: 150, IDF Value: 9.382289428951436
# Term: 153, IDF Value: 9.382289428951436
# Term: 16, IDF Value: 9.382289428951436
# Term: 1625, IDF Value: 8.97682432084327
# Term: 17, IDF Value: 8.97682432084327
# Term: 174, IDF Value: 9.382289428951436
# Term: 1784, IDF Value: 9.382289428951436
# Term: 1802, IDF Value: 9.382289428951436
# Term: 187, IDF Value: 9.382289428951436
# Term: 189, IDF Value: 9.382289428951436
# Term: 1958, IDF Value: 9.382289428951436
# Term: 1976, IDF Value: 9.382289428951436
# Term: 20, IDF Value: 9.382289428951436
# Term: 200, IDF Value: 9.382289428951436
# Term: 203, IDF Value: 9.382289428951436
# Term: 205, IDF Value: 8.97682432084327
# Term: 207, IDF Value: 9.382289428951436
# Term: 23, IDF Value: 9.382289428951436
# Term: 232, IDF Value: 9.382289428951436
# Term: 24, IDF Value: 8.97682432084327
# Term: 25, IDF Value: 8.97682432084327
# Term: 255, IDF Value: 8.97682432084327
# Term: 26, IDF Value: 9.382289428951436
# Term: 262, IDF Value: 9.382289428951436
# Term: 26th, IDF Value: 9.382289428951436
# Term: 28, IDF Value: 9.382289428951436
# Term: 283, IDF Value: 9.382289428951436
# Term: 298, IDF Value: 9.382289428951436
# Term: 30, IDF Value: 9.382289428951436
# Term: 309, IDF Value: 9.382289428951436
# Term: 30th, IDF Value: 9.382289428951436
# Term: 31st, IDF Value: 9.382289428951436
# Term: 324, IDF Value: 9.382289428951436
# Term: 33, IDF Value: 9.382289428951436
# Term: 334, IDF Value: 9.382289428951436
# Term: 338, IDF Value: 9.382289428951436
# Term: 340, IDF Value: 9.382289428951436
# Term: 347, IDF Value: 9.382289428951436
# Term: 3489, IDF Value: 9.382289428951436
# Term: 355, IDF Value: 9.382289428951436
# Term: 357, IDF Value: 9.382289428951436
# Term: 358, IDF Value: 9.382289428951436
# Term: 37, IDF Value: 8.97682432084327
# Term: 391, IDF Value: 8.97682432084327
# Term: 40, IDF Value: 9.382289428951436
# Term: 403, IDF Value: 9.382289428951436
# Term: 405, IDF Value: 9.382289428951436
# Term: 419, IDF Value: 9.382289428951436
# Term: 427, IDF Value: 9.382289428951436
# Term: 438, IDF Value: 9.382289428951436
# Term: 44, IDF Value: 9.382289428951436
# Term: 449, IDF Value: 9.382289428951436
# Term: 473, IDF Value: 9.382289428951436
# Term: 476, IDF Value: 9.382289428951436
# Term: 47j, IDF Value: 9.382289428951436
# Term: 480, IDF Value: 9.382289428951436
# Term: 496, IDF Value: 9.382289428951436
# Term: 50, IDF Value: 8.68914224839149
# Term: 54, IDF Value: 8.97682432084327
# Term: 562, IDF Value: 9.382289428951436
# Term: 564, IDF Value: 9.382289428951436
# Term: 585, IDF Value: 9.382289428951436
# Term: 590, IDF Value: 9.382289428951436
# Term: 60, IDF Value: 9.382289428951436
# Term: 610, IDF Value: 9.382289428951436
# Term: 62, IDF Value: 9.382289428951436
# Term: 627, IDF Value: 9.382289428951436
# Term: 633, IDF Value: 9.382289428951436
# Term: 638, IDF Value: 9.382289428951436
# Term: 639, IDF Value: 9.382289428951436
# Term: 641, IDF Value: 9.382289428951436
# Term: 65, IDF Value: 9.382289428951436
# Term: 660, IDF Value: 9.382289428951436
# Term: 6799, IDF Value: 9.382289428951436
# Term: 680, IDF Value: 9.382289428951436
# Term: 695, IDF Value: 9.382289428951436
# Term: 70, IDF Value: 9.382289428951436
# Term: 71, IDF Value: 8.97682432084327
# Term: 718, IDF Value: 9.382289428951436
# Term: 721, IDF Value: 9.382289428951436
# Term: 727, IDF Value: 9.382289428951436
# Term: 735, IDF Value: 9.382289428951436
# Term: 74, IDF Value: 8.97682432084327
# Term: 751, IDF Value: 9.382289428951436
# Term: 759, IDF Value: 9.382289428951436
# Term: 76, IDF Value: 9.382289428951436
# Term: 760, IDF Value: 9.382289428951436
# Term: 761, IDF Value: 9.382289428951436
# Term: 770, IDF Value: 9.382289428951436
# Term: 771, IDF Value: 9.382289428951436
# Term: 776, IDF Value: 9.382289428951436
# Term: 787, IDF Value: 9.382289428951436
# Term: 79, IDF Value: 9.382289428951436
# Term: 790, IDF Value: 9.382289428951436
# Term: 795, IDF Value: 9.382289428951436
# Term: 82, IDF Value: 9.382289428951436
# Term: 825, IDF Value: 9.382289428951436
# Term: 850, IDF Value: 9.382289428951436
# Term: 89, IDF Value: 8.283677140283327
# Term: 8mm, IDF Value: 9.382289428951436
# Term: 91, IDF Value: 9.382289428951436
# Term: 92, IDF Value: 8.97682432084327
# Term: 926, IDF Value: 9.382289428951436
# Term: 93, IDF Value: 8.97682432084327
# Term: 94, IDF Value: 9.382289428951436
# Term: 95, IDF Value: 9.382289428951436
# Term: 970, IDF Value: 9.382289428951436
# Term: 998, IDF Value: 8.97682432084327
# Term: aa, IDF Value: 9.382289428951436
# Term: aaron, IDF Value: 7.9959950678315455
# Term: abate, IDF Value: 9.382289428951436
# Term: abatement, IDF Value: 9.382289428951436
# Term: abbate, IDF Value: 9.382289428951436
# Term: abbott, IDF Value: 7.677541336713011
# Term: abc, IDF Value: 8.97682432084327
# Term: abdi, IDF Value: 9.382289428951436
# Term: abdu, IDF Value: 9.382289428951436
# Term: abdul, IDF Value: 9.382289428951436
# Term: abdullah, IDF Value: 9.382289428951436
# Term: abdur, IDF Value: 9.382289428951436
# Term: abdus, IDF Value: 9.382289428951436
# Term: abel, IDF Value: 8.465998697077282
# Term: abend, IDF Value: 9.382289428951436
# Term: abercrombie, IDF Value: 9.382289428951436
# Term: aberdeen, IDF Value: 8.465998697077282
# Term: abernathy, IDF Value: 9.382289428951436
# Term: abf, IDF Value: 9.382289428951436
# Term: abid, IDF Value: 9.382289428951436
# Term: abigail, IDF Value: 9.382289428951436
# Term: abington, IDF Value: 9.382289428951436
# Term: abner, IDF Value: 9.382289428951436
# Term: abney, IDF Value: 8.97682432084327
# Term: abood, IDF Value: 9.382289428951436
# Term: abortion, IDF Value: 9.382289428951436
# Term: abourezk, IDF Value: 9.382289428951436
# Term: abraham, IDF Value: 9.382289428951436
# Term: abrahamson, IDF Value: 9.382289428951436
# Term: abram, IDF Value: 9.382289428951436
# Term: abrams, IDF Value: 8.97682432084327
# Term: abramski, IDF Value: 9.382289428951436
# Term: abramson, IDF Value: 9.382289428951436
# Term: abrasive, IDF Value: 9.382289428951436
# Term: abu, IDF Value: 9.382289428951436
# Term: abudu, IDF Value: 9.382289428951436
# Term: abuelhawa, IDF Value: 9.382289428951436
# Term: academic, IDF Value: 9.382289428951436
# Term: academy, IDF Value: 8.283677140283327
# Term: acb, IDF Value: 9.382289428951436
# Term: accardi, IDF Value: 8.68914224839149
# Term: acceptance, IDF Value: 9.382289428951436
# Term: accident, IDF Value: 8.68914224839149
# Term: accountancy, IDF Value: 9.382289428951436
# Term: accounting, IDF Value: 9.382289428951436
# Term: accounts, IDF Value: 8.465998697077282
# Term: ace, IDF Value: 9.382289428951436
# Term: acevedo, IDF Value: 9.382289428951436
# Term: acf, IDF Value: 9.382289428951436
# Term: acheson, IDF Value: 9.382289428951436
# Term: achilli, IDF Value: 9.382289428951436
# Term: acker, IDF Value: 8.97682432084327
# Term: ackerman, IDF Value: 9.382289428951436
# Term: ackermann, IDF Value: 9.382289428951436
# Term: acme, IDF Value: 8.68914224839149
# Term: acosta, IDF Value: 9.382289428951436
# Term: acquisition, IDF Value: 9.382289428951436
# Term: acres, IDF Value: 8.283677140283327
# Term: acri, IDF Value: 9.382289428951436
# Term: actavis, IDF Value: 9.382289428951436
# Term: acting, IDF Value: 6.386557155397445
# Term: action, IDF Value: 7.878212032175162
# Term: activities, IDF Value: 7.9959950678315455
# Term: acton, IDF Value: 9.382289428951436
# Term: actors, IDF Value: 8.97682432084327
# Term: acuff, IDF Value: 9.382289428951436
# Term: ad, IDF Value: 8.465998697077282
# Term: ada, IDF Value: 9.382289428951436
# Term: adam, IDF Value: 9.382289428951436
# Term: adamo, IDF Value: 9.382289428951436
# Term: adams, IDF Value: 7.07970433595739
# Term: adamson, IDF Value: 8.97682432084327
# Term: adarand, IDF Value: 8.68914224839149
# Term: aday, IDF Value: 9.382289428951436
# Term: adderley, IDF Value: 9.382289428951436
# Term: addington, IDF Value: 9.382289428951436
# Term: addition, IDF Value: 9.382289428951436
# Term: addonizio, IDF Value: 9.382289428951436
# Term: adelaide, IDF Value: 9.382289428951436
# Term: adickes, IDF Value: 9.382289428951436
# Term: adjustment, IDF Value: 9.382289428951436
# Term: adkins, IDF Value: 8.68914224839149
# Term: adler, IDF Value: 9.382289428951436
# Term: admininistrator, IDF Value: 9.382289428951436
# Term: administration, IDF Value: 6.8973827791634355
# Term: administrator, IDF Value: 5.656596001714783
# Term: administrators, IDF Value: 7.9959950678315455
# Term: administratrator, IDF Value: 9.382289428951436
# Term: administratrix, IDF Value: 6.29124697559312
# Term: admissions, IDF Value: 9.382289428951436
# Term: adoptive, IDF Value: 9.382289428951436
# Term: adrian, IDF Value: 8.68914224839149
# Term: adult, IDF Value: 8.465998697077282
# Term: advanced, IDF Value: 8.97682432084327
# Term: advancement, IDF Value: 7.367386408409171
# Term: advantage, IDF Value: 9.382289428951436
# Term: advertising, IDF Value: 8.68914224839149
# Term: advisors, IDF Value: 8.97682432084327
# Term: advisory, IDF Value: 8.97682432084327
# Term: advocacy, IDF Value: 9.382289428951436
# Term: aerea, IDF Value: 9.382289428951436
# Term: aeree, IDF Value: 9.382289428951436
# Term: aereo, IDF Value: 9.382289428951436
# Term: aero, IDF Value: 8.68914224839149
# Term: aerojet, IDF Value: 9.382289428951436
# Term: aeronautical, IDF Value: 9.382289428951436
# Term: aeronautics, IDF Value: 7.878212032175162
# Term: aerospace, IDF Value: 7.5104872520498445
# Term: aerospatiale, IDF Value: 9.382289428951436
# Term: aetna, IDF Value: 7.772851516517336
# Term: affairs, IDF Value: 7.1309976303449405
# Term: affiliated, IDF Value: 8.465998697077282
# Term: affiliates, IDF Value: 9.382289428951436
# Term: affirmative, IDF Value: 9.382289428951436
# Term: affolder, IDF Value: 9.382289428951436
# Term: affronti, IDF Value: 9.382289428951436
# Term: afl, IDF Value: 5.564577102994531
# Term: aflcio, IDF Value: 9.382289428951436
# Term: afroyim, IDF Value: 9.382289428951436
# Term: aft, IDF Value: 9.382289428951436
# Term: afton, IDF Value: 9.382289428951436
# Term: ag, IDF Value: 8.283677140283327
# Term: against, IDF Value: 8.68914224839149
# Term: agard, IDF Value: 9.382289428951436
# Term: agee, IDF Value: 9.382289428951436
# Term: agencies, IDF Value: 8.97682432084327
# Term: agency, IDF Value: 6.124192890929954
# Term: agent, IDF Value: 9.382289428951436
# Term: agents, IDF Value: 8.68914224839149
# Term: agins, IDF Value: 9.382289428951436
# Term: agnew, IDF Value: 9.382289428951436
# Term: agostini, IDF Value: 9.382289428951436
# Term: agosto, IDF Value: 9.382289428951436
# Term: agricultural, IDF Value: 7.2422232654551655
# Term: agriculture, IDF Value: 6.609700706711655
# Term: agron, IDF Value: 9.382289428951436
# Term: agrosciences, IDF Value: 9.382289428951436
# Term: aguilar, IDF Value: 8.68914224839149
# Term: aguillard, IDF Value: 9.382289428951436
# Term: aguirre, IDF Value: 9.382289428951436
# Term: agurs, IDF Value: 9.382289428951436
# Term: agyei, IDF Value: 9.382289428951436
# Term: ahern, IDF Value: 9.382289428951436
# Term: ahlborn, IDF Value: 9.382289428951436
# Term: ahlers, IDF Value: 9.382289428951436
# Term: ahmed, IDF Value: 8.97682432084327
# Term: ahrens, IDF Value: 9.382289428951436
# Term: aid, IDF Value: 7.9959950678315455
# Term: aids, IDF Value: 9.382289428951436
# Term: aiello, IDF Value: 9.382289428951436
# Term: aiken, IDF Value: 8.68914224839149
# Term: aikens, IDF Value: 8.97682432084327
# Term: air, IDF Value: 6.20423559860349
# Term: aircraft, IDF Value: 7.2422232654551655
# Term: airline, IDF Value: 9.382289428951436
# Term: airlines, IDF Value: 6.743232099336177
# Term: airport, IDF Value: 8.68914224839149
# Term: airports, IDF Value: 9.382289428951436
# Term: airways, IDF Value: 7.9959950678315455
# Term: aka, IDF Value: 6.674239227849226
# Term: akamai, IDF Value: 9.382289428951436
# Term: ake, IDF Value: 9.382289428951436
# Term: akins, IDF Value: 9.382289428951436
# Term: akio, IDF Value: 9.382289428951436
# Term: akos, IDF Value: 9.382289428951436
# Term: akron, IDF Value: 8.465998697077282
# Term: aktiebolaget, IDF Value: 9.382289428951436
# Term: aktiengesellschaft, IDF Value: 8.97682432084327
# Term: al, IDF Value: 1.6984254486950063
# Term: ala, IDF Value: 8.97682432084327
# Term: alabama, IDF Value: 5.598099795033175
# Term: aladdin, IDF Value: 9.382289428951436
# Term: alafabco, IDF Value: 9.382289428951436
# Term: alameda, IDF Value: 8.283677140283327
# Term: alamo, IDF Value: 8.97682432084327
# Term: alan, IDF Value: 8.68914224839149
# Term: alaska, IDF Value: 6.674239227849226
# Term: albanese, IDF Value: 9.382289428951436
# Term: albemarle, IDF Value: 8.97682432084327
# Term: albernaz, IDF Value: 9.382289428951436
# Term: albers, IDF Value: 9.382289428951436
# Term: albert, IDF Value: 7.677541336713011
# Term: alberta, IDF Value: 9.382289428951436
# Term: albertini, IDF Value: 9.382289428951436
# Term: alberto, IDF Value: 7.677541336713011
# Term: albertson, IDF Value: 8.68914224839149
# Term: albrecht, IDF Value: 8.97682432084327
# Term: albright, IDF Value: 8.97682432084327
# Term: alcala, IDF Value: 9.382289428951436
# Term: alcan, IDF Value: 9.382289428951436
# Term: alcea, IDF Value: 8.97682432084327
# Term: alco, IDF Value: 9.382289428951436
# Term: alcoa, IDF Value: 9.382289428951436
# Term: alcohol, IDF Value: 8.465998697077282
# Term: alcoholic, IDF Value: 8.283677140283327
# Term: alcorta, IDF Value: 9.382289428951436
# Term: alden, IDF Value: 9.382289428951436
# Term: alderman, IDF Value: 9.382289428951436
# Term: aldinger, IDF Value: 9.382289428951436
# Term: aldona, IDF Value: 9.382289428951436
# Term: aldrich, IDF Value: 8.97682432084327
# Term: alejandra, IDF Value: 9.382289428951436
# Term: alejandro, IDF Value: 9.382289428951436
# Term: alene, IDF Value: 9.382289428951436
# Term: alessi, IDF Value: 9.382289428951436
# Term: aletha, IDF Value: 9.382289428951436
# Term: alex, IDF Value: 8.68914224839149
# Term: alexander, IDF Value: 7.3028478872716
# Term: alexandre, IDF Value: 9.382289428951436
# Term: alexandria, IDF Value: 8.68914224839149
# Term: alexis, IDF Value: 8.97682432084327
# Term: alfalfa, IDF Value: 8.97682432084327
# Term: alfonso, IDF Value: 8.97682432084327
# Term: alfonzo, IDF Value: 9.382289428951436
# Term: alford, IDF Value: 8.97682432084327
# Term: alfred, IDF Value: 8.283677140283327
# Term: algoma, IDF Value: 9.382289428951436
# Term: algonquin, IDF Value: 9.382289428951436
# Term: ali, IDF Value: 8.129526460456068
# Term: alias, IDF Value: 7.9959950678315455
# Term: alice, IDF Value: 8.97682432084327
# Term: alicia, IDF Value: 9.382289428951436
# Term: alida, IDF Value: 9.382289428951436
# Term: alien, IDF Value: 7.2422232654551655
# Term: alison, IDF Value: 9.382289428951436
# Term: alitalia, IDF Value: 9.382289428951436
# Term: alkali, IDF Value: 9.382289428951436
# Term: all, IDF Value: 7.677541336713011
# Term: allain, IDF Value: 9.382289428951436
# Term: allan, IDF Value: 8.283677140283327
# Term: allapattah, IDF Value: 9.382289428951436
# Term: allard, IDF Value: 9.382289428951436
# Term: allcare, IDF Value: 9.382289428951436
# Term: allee, IDF Value: 9.382289428951436
# Term: alleghany, IDF Value: 8.68914224839149
# Term: allegheny, IDF Value: 8.129526460456068
# Term: allen, IDF Value: 6.674239227849226
# Term: allenberg, IDF Value: 9.382289428951436
# Term: allentown, IDF Value: 8.68914224839149
# Term: alleyne, IDF Value: 9.382289428951436
# Term: alliance, IDF Value: 8.465998697077282
# Term: allianz, IDF Value: 9.382289428951436
# Term: allied, IDF Value: 7.5104872520498445
# Term: allis, IDF Value: 8.97682432084327
# Term: allison, IDF Value: 8.68914224839149
# Term: alloyd, IDF Value: 9.382289428951436
# Term: allstate, IDF Value: 8.68914224839149
# Term: alma, IDF Value: 8.97682432084327
# Term: almeida, IDF Value: 9.382289428951436
# Term: almendarez, IDF Value: 9.382289428951436
# Term: almota, IDF Value: 9.382289428951436
# Term: aloha, IDF Value: 9.382289428951436
# Term: alonzo, IDF Value: 9.382289428951436
# Term: aloyzas, IDF Value: 9.382289428951436
# Term: alpers, IDF Value: 9.382289428951436
# Term: alpert, IDF Value: 9.382289428951436
# Term: alphonso, IDF Value: 8.97682432084327
# Term: alpine, IDF Value: 9.382289428951436
# Term: already, IDF Value: 9.382289428951436
# Term: also, IDF Value: 9.382289428951436
# Term: alstate, IDF Value: 9.382289428951436
# Term: althon, IDF Value: 9.382289428951436
# Term: altmann, IDF Value: 9.382289428951436
# Term: alto, IDF Value: 9.382289428951436
# Term: alton, IDF Value: 9.382289428951436
# Term: altria, IDF Value: 9.382289428951436
# Term: aluminium, IDF Value: 9.382289428951436
# Term: aluminum, IDF Value: 8.283677140283327
# Term: alvarado, IDF Value: 8.97682432084327
# Term: alvarez, IDF Value: 7.878212032175162
# Term: alvez, IDF Value: 9.382289428951436
# Term: alvin, IDF Value: 9.382289428951436
# Term: alyeska, IDF Value: 9.382289428951436
# Term: am, IDF Value: 8.97682432084327
# Term: amadeo, IDF Value: 9.382289428951436
# Term: amalgamated, IDF Value: 7.5104872520498445
# Term: amanda, IDF Value: 9.382289428951436
# Term: amant, IDF Value: 9.382289428951436
# Term: amara, IDF Value: 9.382289428951436
# Term: amarillo, IDF Value: 9.382289428951436
# Term: amax, IDF Value: 9.382289428951436
# Term: ambach, IDF Value: 9.382289428951436
# Term: ambassador, IDF Value: 9.382289428951436
# Term: amchem, IDF Value: 9.382289428951436
# Term: amclyde, IDF Value: 9.382289428951436
# Term: amell, IDF Value: 9.382289428951436
# Term: amen, IDF Value: 9.382289428951436
# Term: amerada, IDF Value: 8.283677140283327
# Term: america, IDF Value: 5.085004022732645
# Term: american, IDF Value: 5.20023928631023
# Term: americans, IDF Value: 8.97682432084327
# Term: americold, IDF Value: 9.382289428951436
# Term: amerik, IDF Value: 8.97682432084327
# Term: amerika, IDF Value: 9.382289428951436
# Term: ameristaff, IDF Value: 9.382289428951436
# Term: amgen, IDF Value: 8.97682432084327
# Term: ammex, IDF Value: 9.382289428951436
# Term: amnesty, IDF Value: 9.382289428951436
# Term: amoco, IDF Value: 8.68914224839149
# Term: amos, IDF Value: 8.68914224839149
# Term: amp, IDF Value: 9.382289428951436
# Term: amusement, IDF Value: 8.97682432084327
# Term: an, IDF Value: 8.283677140283327
# Term: ana, IDF Value: 8.97682432084327
# Term: analysts, IDF Value: 9.382289428951436
# Term: anastaplo, IDF Value: 9.382289428951436
# Term: anchor, IDF Value: 9.382289428951436
# Term: ancillary, IDF Value: 8.97682432084327
# Term: and, IDF Value: 3.5329646490045765
# Term: anders, IDF Value: 8.97682432084327
# Term: andersen, IDF Value: 8.97682432084327
# Term: anderson, IDF Value: 6.708140779524907
# Term: andrade, IDF Value: 9.382289428951436
# Term: andre, IDF Value: 8.68914224839149
# Term: andrea, IDF Value: 9.382289428951436
# Term: andreas, IDF Value: 9.382289428951436
# Term: andres, IDF Value: 9.382289428951436
# Term: andresen, IDF Value: 9.382289428951436
# Term: andrew, IDF Value: 8.129526460456068
# Term: andrews, IDF Value: 8.129526460456068
# Term: andrus, IDF Value: 7.878212032175162
# Term: angel, IDF Value: 8.283677140283327
# Term: angela, IDF Value: 8.97682432084327
# Term: angeles, IDF Value: 6.491917671055271
# Term: angelet, IDF Value: 9.382289428951436
# Term: angelo, IDF Value: 8.97682432084327
# Term: angelone, IDF Value: 8.68914224839149
# Term: angus, IDF Value: 9.382289428951436
# Term: anh, IDF Value: 9.382289428951436
# Term: anheuser, IDF Value: 8.97682432084327
# Term: anibal, IDF Value: 9.382289428951436
# Term: animalfeeds, IDF Value: 9.382289428951436
# Term: animals, IDF Value: 9.382289428951436
# Term: aniskoff, IDF Value: 9.382289428951436
# Term: anita, IDF Value: 9.382289428951436
# Term: ankenbrandt, IDF Value: 9.382289428951436
# Term: ann, IDF Value: 8.68914224839149
# Term: anna, IDF Value: 8.97682432084327
# Term: anne, IDF Value: 7.9959950678315455
# Term: annette, IDF Value: 8.97682432084327
# Term: annuity, IDF Value: 8.465998697077282
# Term: anonymous, IDF Value: 9.382289428951436
# Term: anr, IDF Value: 9.382289428951436
# Term: ansonia, IDF Value: 9.382289428951436
# Term: antelope, IDF Value: 9.382289428951436
# Term: anthony, IDF Value: 7.185064851615216
# Term: anti, IDF Value: 8.68914224839149
# Term: antoine, IDF Value: 8.68914224839149
# Term: antone, IDF Value: 9.382289428951436
# Term: antonelli, IDF Value: 9.382289428951436
# Term: antonio, IDF Value: 7.590529959723381
# Term: antonios, IDF Value: 9.382289428951436
# Term: antony, IDF Value: 9.382289428951436
# Term: anup, IDF Value: 9.382289428951436
# Term: anza, IDF Value: 8.97682432084327
# Term: apache, IDF Value: 7.9959950678315455
# Term: apartment, IDF Value: 9.382289428951436
# Term: apcc, IDF Value: 9.382289428951436
# Term: apel, IDF Value: 9.382289428951436
# Term: apex, IDF Value: 9.382289428951436
# Term: apfel, IDF Value: 8.68914224839149
# Term: apfelbaum, IDF Value: 9.382289428951436
# Term: apodaca, IDF Value: 9.382289428951436
# Term: apparel, IDF Value: 9.382289428951436
# Term: appeal, IDF Value: 8.97682432084327
# Term: appeals, IDF Value: 7.367386408409171
# Term: appellants, IDF Value: 8.97682432084327
# Term: appellate, IDF Value: 8.97682432084327
# Term: apple, IDF Value: 9.382289428951436
# Term: appliance, IDF Value: 9.382289428951436
# Term: appliances, IDF Value: 9.382289428951436
# Term: applicants, IDF Value: 9.382289428951436
# Term: application, IDF Value: 9.382289428951436
# Term: apprendi, IDF Value: 9.382289428951436
# Term: apprentices, IDF Value: 8.465998697077282
# Term: appurtenances, IDF Value: 9.382289428951436
# Term: april, IDF Value: 9.382289428951436
# Term: aptheker, IDF Value: 9.382289428951436
# Term: aqueduct, IDF Value: 9.382289428951436
# Term: aquilino, IDF Value: 9.382289428951436
# Term: arab, IDF Value: 9.382289428951436
# Term: arabia, IDF Value: 8.97682432084327
# Term: arabian, IDF Value: 8.97682432084327
# Term: aragon, IDF Value: 9.382289428951436
# Term: arave, IDF Value: 8.97682432084327
# Term: arbaugh, IDF Value: 9.382289428951436
# Term: arboleda, IDF Value: 9.382289428951436
# Term: arc, IDF Value: 9.382289428951436
# Term: arcades, IDF Value: 9.382289428951436
# Term: arcadia, IDF Value: 9.382289428951436
# Term: arcara, IDF Value: 9.382289428951436
# Term: arceneaux, IDF Value: 9.382289428951436
# Term: arceo, IDF Value: 9.382289428951436
# Term: archawski, IDF Value: 9.382289428951436
# Term: archbishop, IDF Value: 9.382289428951436
# Term: archdiocese, IDF Value: 9.382289428951436
# Term: archer, IDF Value: 9.382289428951436
# Term: archie, IDF Value: 9.382289428951436
# Term: architects, IDF Value: 9.382289428951436
# Term: archives, IDF Value: 9.382289428951436
# Term: archivist, IDF Value: 9.382289428951436
# Term: arciniega, IDF Value: 9.382289428951436
# Term: arctic, IDF Value: 9.382289428951436
# Term: ardestani, IDF Value: 9.382289428951436
# Term: area, IDF Value: 8.129526460456068
# Term: areas, IDF Value: 9.382289428951436
# Term: argentina, IDF Value: 8.68914224839149
# Term: argentine, IDF Value: 9.382289428951436
# Term: argersinger, IDF Value: 9.382289428951436
# Term: arguelles, IDF Value: 9.382289428951436
# Term: ari, IDF Value: 9.382289428951436
# Term: ariadne, IDF Value: 9.382289428951436
# Term: arizona, IDF Value: 5.644619810668067
# Term: arizonans, IDF Value: 9.382289428951436
# Term: arkansas, IDF Value: 6.014993598964962
# Term: arkison, IDF Value: 9.382289428951436
# Term: arkoma, IDF Value: 9.382289428951436
# Term: arlan, IDF Value: 9.382289428951436
# Term: arlen, IDF Value: 9.382289428951436
# Term: arlene, IDF Value: 9.382289428951436
# Term: arline, IDF Value: 9.382289428951436
# Term: arlington, IDF Value: 7.9959950678315455
# Term: armarcion, IDF Value: 9.382289428951436
# Term: armco, IDF Value: 8.97682432084327
# Term: armed, IDF Value: 8.97682432084327
# Term: armour, IDF Value: 8.68914224839149
# Term: arms, IDF Value: 9.382289428951436
# Term: armstrong, IDF Value: 7.9959950678315455
# Term: army, IDF Value: 7.367386408409171
# Term: arn, IDF Value: 9.382289428951436
# Term: arnett, IDF Value: 8.97682432084327
# Term: arnheim, IDF Value: 9.382289428951436
# Term: arnold, IDF Value: 7.772851516517336
# Term: aro, IDF Value: 8.97682432084327
# Term: aron, IDF Value: 9.382289428951436
# Term: aronson, IDF Value: 9.382289428951436
# Term: aroostook, IDF Value: 8.97682432084327
# Term: arra, IDF Value: 9.382289428951436
# Term: arriaza, IDF Value: 9.382289428951436
# Term: arrow, IDF Value: 8.68914224839149
# Term: arrowsmith, IDF Value: 9.382289428951436
# Term: arroyo, IDF Value: 9.382289428951436
# Term: arsdall, IDF Value: 9.382289428951436
# Term: arsenault, IDF Value: 9.382289428951436
# Term: art, IDF Value: 9.382289428951436
# Term: arteaga, IDF Value: 9.382289428951436
# Term: arthur, IDF Value: 7.185064851615216
# Term: article, IDF Value: 9.382289428951436
# Term: artist, IDF Value: 9.382289428951436
# Term: artists, IDF Value: 8.68914224839149
# Term: arts, IDF Value: 8.465998697077282
# Term: artukovic, IDF Value: 9.382289428951436
# Term: arturo, IDF Value: 9.382289428951436
# Term: artuz, IDF Value: 9.382289428951436
# Term: artware, IDF Value: 9.382289428951436
# Term: arvizu, IDF Value: 9.382289428951436
# Term: as, IDF Value: 5.374956243718965
# Term: asahi, IDF Value: 9.382289428951436
# Term: asarco, IDF Value: 8.68914224839149
# Term: asgrow, IDF Value: 9.382289428951436
# Term: ash, IDF Value: 8.68914224839149
# Term: ashbel, IDF Value: 9.382289428951436
# Term: ashcroft, IDF Value: 7.590529959723381
# Term: ashdown, IDF Value: 9.382289428951436
# Term: ashe, IDF Value: 8.97682432084327
# Term: ashford, IDF Value: 9.382289428951436
# Term: ashland, IDF Value: 9.382289428951436
# Term: ashmus, IDF Value: 9.382289428951436
# Term: ashton, IDF Value: 9.382289428951436
# Term: asia, IDF Value: 9.382289428951436
# Term: asid, IDF Value: 9.382289428951436
# Term: askew, IDF Value: 8.97682432084327
# Term: aspen, IDF Value: 9.382289428951436
# Term: asphalt, IDF Value: 8.97682432084327
# Term: ass, IDF Value: 8.68914224839149
# Term: asselta, IDF Value: 9.382289428951436
# Term: assembly, IDF Value: 8.465998697077282
# Term: assessment, IDF Value: 8.97682432084327
# Term: assessor, IDF Value: 8.283677140283327
# Term: assessors, IDF Value: 8.97682432084327
# Term: assets, IDF Value: 9.382289428951436
# Term: assibi, IDF Value: 9.382289428951436
# Term: assistance, IDF Value: 8.68914224839149
# Term: assistant, IDF Value: 8.283677140283327
# Term: assn, IDF Value: 6.386557155397445
# Term: assns, IDF Value: 9.382289428951436
# Term: associate, IDF Value: 8.97682432084327
# Term: associated, IDF Value: 7.772851516517336
# Term: associates, IDF Value: 6.708140779524907
# Term: association, IDF Value: 4.828412537350895
# Term: associations, IDF Value: 7.5104872520498445
# Term: assortment, IDF Value: 9.382289428951436
# Term: assurance, IDF Value: 8.465998697077282
# Term: astoria, IDF Value: 9.382289428951436
# Term: astra, IDF Value: 9.382289428951436
# Term: astrue, IDF Value: 8.97682432084327
# Term: astrup, IDF Value: 9.382289428951436
# Term: asylum, IDF Value: 9.382289428951436
# Term: at, IDF Value: 6.8973827791634355
# Term: atascadero, IDF Value: 9.382289428951436
# Term: atchison, IDF Value: 7.590529959723381
# Term: atchley, IDF Value: 8.97682432084327
# Term: atherton, IDF Value: 9.382289428951436
# Term: athletic, IDF Value: 8.283677140283327
# Term: athletics, IDF Value: 9.382289428951436
# Term: atkins, IDF Value: 8.283677140283327
# Term: atkinson, IDF Value: 8.465998697077282
# Term: atlanta, IDF Value: 8.283677140283327
# Term: atlantic, IDF Value: 6.641449405026235
# Term: atlas, IDF Value: 8.465998697077282
# Term: atlass, IDF Value: 9.382289428951436
# Term: atomic, IDF Value: 8.129526460456068
# Term: atonio, IDF Value: 9.382289428951436
# Term: attea, IDF Value: 9.382289428951436
# Term: attendants, IDF Value: 8.68914224839149
# Term: attorney, IDF Value: 4.762230630469594
# Term: attwood, IDF Value: 9.382289428951436
# Term: atwater, IDF Value: 9.382289428951436
# Term: au, IDF Value: 9.382289428951436
# Term: auburn, IDF Value: 9.382289428951436
# Term: auciello, IDF Value: 9.382289428951436
# Term: auditor, IDF Value: 8.465998697077282
# Term: audrey, IDF Value: 9.382289428951436
# Term: audubon, IDF Value: 9.382289428951436
# Term: auer, IDF Value: 9.382289428951436
# Term: augenblick, IDF Value: 9.382289428951436
# Term: august, IDF Value: 9.382289428951436
# Term: augusta, IDF Value: 9.382289428951436
# Term: aurelia, IDF Value: 9.382289428951436
# Term: aurelio, IDF Value: 9.382289428951436
# Term: aurora, IDF Value: 9.382289428951436
# Term: ausbie, IDF Value: 9.382289428951436
# Term: austin, IDF Value: 7.677541336713011
# Term: australia, IDF Value: 8.97682432084327
# Term: austria, IDF Value: 9.382289428951436
# Term: austrian, IDF Value: 9.382289428951436
# Term: authority, IDF Value: 6.337766991228013
# Term: authorized, IDF Value: 9.382289428951436
# Term: authors, IDF Value: 8.97682432084327
# Term: auto, IDF Value: 7.9959950678315455
# Term: autolite, IDF Value: 9.382289428951436
# Term: automated, IDF Value: 9.382289428951436
# Term: automatic, IDF Value: 8.465998697077282
# Term: automobile, IDF Value: 7.2422232654551655
# Term: automotive, IDF Value: 9.382289428951436
# Term: autry, IDF Value: 9.382289428951436
# Term: avagliano, IDF Value: 9.382289428951436
# Term: avansino, IDF Value: 9.382289428951436
# Term: avco, IDF Value: 8.97682432084327
# Term: avent, IDF Value: 9.382289428951436
# Term: avenue, IDF Value: 8.97682432084327
# Term: avery, IDF Value: 8.465998697077282
# Term: aviall, IDF Value: 9.382289428951436
# Term: aviation, IDF Value: 8.283677140283327
# Term: avocado, IDF Value: 8.97682432084327
# Term: avondale, IDF Value: 9.382289428951436
# Term: avrech, IDF Value: 9.382289428951436
# Term: avron, IDF Value: 9.382289428951436
# Term: axle, IDF Value: 9.382289428951436
# Term: ayala, IDF Value: 9.382289428951436
# Term: aye, IDF Value: 9.382289428951436
# Term: ayers, IDF Value: 8.97682432084327
# Term: ayotte, IDF Value: 9.382289428951436
# Term: ayrshire, IDF Value: 8.97682432084327
# Term: azel, IDF Value: 9.382289428951436
# Term: azioni, IDF Value: 9.382289428951436
# Term: aznavorian, IDF Value: 9.382289428951436
# Term: azzam, IDF Value: 9.382289428951436
# Term: baal, IDF Value: 9.382289428951436
# Term: babalu, IDF Value: 9.382289428951436
# Term: babb, IDF Value: 9.382289428951436
# Term: babbitt, IDF Value: 8.465998697077282
# Term: babcock, IDF Value: 9.382289428951436
# Term: baby, IDF Value: 9.382289428951436
# Term: bacchus, IDF Value: 9.382289428951436
# Term: bachellar, IDF Value: 9.382289428951436
# Term: bachowski, IDF Value: 9.382289428951436
# Term: bacon, IDF Value: 9.382289428951436
# Term: bacto, IDF Value: 9.382289428951436
# Term: badaracco, IDF Value: 9.382289428951436
# Term: baer, IDF Value: 9.382289428951436
# Term: bagamasbad, IDF Value: 9.382289428951436
# Term: baggett, IDF Value: 9.382289428951436
# Term: baggot, IDF Value: 9.382289428951436
# Term: bagley, IDF Value: 9.382289428951436
# Term: bagwell, IDF Value: 9.382289428951436
# Term: bailess, IDF Value: 9.382289428951436
# Term: bailey, IDF Value: 7.9959950678315455
# Term: baines, IDF Value: 9.382289428951436
# Term: bair, IDF Value: 9.382289428951436
# Term: baird, IDF Value: 8.465998697077282
# Term: bajakajian, IDF Value: 9.382289428951436
# Term: baker, IDF Value: 7.436379279896123
# Term: bakeries, IDF Value: 9.382289428951436
# Term: bakery, IDF Value: 8.68914224839149
# Term: baking, IDF Value: 8.68914224839149
# Term: bakke, IDF Value: 9.382289428951436
# Term: baldasar, IDF Value: 9.382289428951436
# Term: baldi, IDF Value: 9.382289428951436
# Term: baldonado, IDF Value: 9.382289428951436
# Term: baldrige, IDF Value: 9.382289428951436
# Term: baldwin, IDF Value: 8.283677140283327
# Term: balhoff, IDF Value: 9.382289428951436
# Term: balisok, IDF Value: 9.382289428951436
# Term: balkcom, IDF Value: 9.382289428951436
# Term: ball, IDF Value: 7.9959950678315455
# Term: ballard, IDF Value: 8.68914224839149
# Term: ballentine, IDF Value: 9.382289428951436
# Term: ballew, IDF Value: 9.382289428951436
# Term: ballroom, IDF Value: 9.382289428951436
# Term: balsys, IDF Value: 9.382289428951436
# Term: baltimore, IDF Value: 6.984394156153066
# Term: banco, IDF Value: 8.465998697077282
# Term: bancorp, IDF Value: 8.68914224839149
# Term: bancorporation, IDF Value: 8.97682432084327
# Term: band, IDF Value: 7.436379279896123
# Term: bandemer, IDF Value: 9.382289428951436
# Term: bandrowski, IDF Value: 9.382289428951436
# Term: bands, IDF Value: 8.465998697077282
# Term: bangor, IDF Value: 8.97682432084327
# Term: bank, IDF Value: 5.27964606391464
# Term: bankamerica, IDF Value: 9.382289428951436
# Term: bankchampaign, IDF Value: 9.382289428951436
# Term: bankers, IDF Value: 8.129526460456068
# Term: banking, IDF Value: 8.97682432084327
# Term: bankruptcy, IDF Value: 6.856560784643181
# Term: banks, IDF Value: 7.590529959723381
# Term: bankshares, IDF Value: 9.382289428951436
# Term: banner, IDF Value: 8.68914224839149
# Term: bannercraft, IDF Value: 9.382289428951436
# Term: bannister, IDF Value: 9.382289428951436
# Term: bannon, IDF Value: 9.382289428951436
# Term: bantam, IDF Value: 9.382289428951436
# Term: baptist, IDF Value: 8.97682432084327
# Term: bar, IDF Value: 6.8973827791634355
# Term: barack, IDF Value: 9.382289428951436
# Term: baral, IDF Value: 9.382289428951436
# Term: barasch, IDF Value: 9.382289428951436
# Term: barbara, IDF Value: 7.590529959723381
# Term: barber, IDF Value: 8.283677140283327
# Term: barbour, IDF Value: 9.382289428951436
# Term: barcelo, IDF Value: 9.382289428951436
# Term: barchi, IDF Value: 9.382289428951436
# Term: barclay, IDF Value: 9.382289428951436
# Term: barclays, IDF Value: 9.382289428951436
# Term: barefoot, IDF Value: 9.382289428951436
# Term: barenblatt, IDF Value: 9.382289428951436
# Term: baresel, IDF Value: 9.382289428951436
# Term: barez, IDF Value: 9.382289428951436
# Term: bargaining, IDF Value: 9.382289428951436
# Term: barge, IDF Value: 7.9959950678315455
# Term: barinem, IDF Value: 9.382289428951436
# Term: barion, IDF Value: 9.382289428951436
# Term: barkat, IDF Value: 9.382289428951436
# Term: barker, IDF Value: 8.97682432084327
# Term: barkes, IDF Value: 9.382289428951436
# Term: barlow, IDF Value: 8.68914224839149
# Term: barnard, IDF Value: 9.382289428951436
# Term: barneck, IDF Value: 9.382289428951436
# Term: barnes, IDF Value: 7.9959950678315455
# Term: barnett, IDF Value: 8.68914224839149
# Term: barney, IDF Value: 8.97682432084327
# Term: barnhart, IDF Value: 8.283677140283327
# Term: barnhill, IDF Value: 9.382289428951436
# Term: barnstable, IDF Value: 9.382289428951436
# Term: barr, IDF Value: 8.68914224839149
# Term: barrack, IDF Value: 9.382289428951436
# Term: barracks, IDF Value: 9.382289428951436
# Term: barre, IDF Value: 9.382289428951436
# Term: barrentine, IDF Value: 9.382289428951436
# Term: barrera, IDF Value: 9.382289428951436
# Term: barresi, IDF Value: 9.382289428951436
# Term: barrett, IDF Value: 8.465998697077282
# Term: barrows, IDF Value: 9.382289428951436
# Term: barry, IDF Value: 7.9959950678315455
# Term: barsky, IDF Value: 9.382289428951436
# Term: bart, IDF Value: 9.382289428951436
# Term: bartels, IDF Value: 9.382289428951436
# Term: bartenders, IDF Value: 8.68914224839149
# Term: barthe, IDF Value: 9.382289428951436
# Term: bartholomew, IDF Value: 8.97682432084327
# Term: bartkus, IDF Value: 8.97682432084327
# Term: bartlett, IDF Value: 8.68914224839149
# Term: bartley, IDF Value: 9.382289428951436
# Term: bartnicki, IDF Value: 9.382289428951436
# Term: barton, IDF Value: 9.382289428951436
# Term: bartone, IDF Value: 9.382289428951436
# Term: bartow, IDF Value: 9.382289428951436
# Term: baruch, IDF Value: 9.382289428951436
# Term: baseball, IDF Value: 8.97682432084327
# Term: based, IDF Value: 9.382289428951436
# Term: basham, IDF Value: 9.382289428951436
# Term: bashe, IDF Value: 9.382289428951436
# Term: basic, IDF Value: 8.68914224839149
# Term: basim, IDF Value: 9.382289428951436
# Term: basin, IDF Value: 8.68914224839149
# Term: bass, IDF Value: 8.97682432084327
# Term: basye, IDF Value: 9.382289428951436
# Term: batchelder, IDF Value: 8.97682432084327
# Term: bateman, IDF Value: 9.382289428951436
# Term: bates, IDF Value: 8.465998697077282
# Term: bateson, IDF Value: 9.382289428951436
# Term: bath, IDF Value: 9.382289428951436
# Term: baton, IDF Value: 9.382289428951436
# Term: batson, IDF Value: 9.382289428951436
# Term: batterton, IDF Value: 9.382289428951436
# Term: battery, IDF Value: 8.97682432084327
# Term: battin, IDF Value: 9.382289428951436
# Term: bauer, IDF Value: 9.382289428951436
# Term: bauman, IDF Value: 9.382289428951436
# Term: baumet, IDF Value: 9.382289428951436
# Term: baumgartner, IDF Value: 9.382289428951436
# Term: bauxites, IDF Value: 9.382289428951436
# Term: baxley, IDF Value: 8.97682432084327
# Term: baxstrom, IDF Value: 9.382289428951436
# Term: baxter, IDF Value: 9.382289428951436
# Term: bay, IDF Value: 7.772851516517336
# Term: bayer, IDF Value: 8.97682432084327
# Term: bayless, IDF Value: 9.382289428951436
# Term: baylor, IDF Value: 9.382289428951436
# Term: bayside, IDF Value: 9.382289428951436
# Term: bayview, IDF Value: 9.382289428951436
# Term: baze, IDF Value: 9.382289428951436
# Term: bazemore, IDF Value: 9.382289428951436
# Term: bazley, IDF Value: 9.382289428951436
# Term: bazzetta, IDF Value: 9.382289428951436
# Term: bazzle, IDF Value: 9.382289428951436
# Term: bd, IDF Value: 8.68914224839149
# Term: be, IDF Value: 8.97682432084327
# Term: beach, IDF Value: 8.129526460456068
# Term: beacon, IDF Value: 8.97682432084327
# Term: beal, IDF Value: 9.382289428951436
# Term: beals, IDF Value: 9.382289428951436
# Term: beam, IDF Value: 8.97682432084327
# Term: bean, IDF Value: 9.382289428951436
# Term: beard, IDF Value: 8.283677140283327
# Term: bearden, IDF Value: 9.382289428951436
# Term: bearing, IDF Value: 9.382289428951436
# Term: beasley, IDF Value: 9.382289428951436
# Term: beatrice, IDF Value: 8.97682432084327
# Term: beaty, IDF Value: 9.382289428951436
# Term: beauharnais, IDF Value: 9.382289428951436
# Term: beaumont, IDF Value: 9.382289428951436
# Term: beaver, IDF Value: 9.382289428951436
# Term: beazer, IDF Value: 9.382289428951436
# Term: beck, IDF Value: 8.129526460456068
# Term: becker, IDF Value: 8.97682432084327
# Term: beckley, IDF Value: 9.382289428951436
# Term: beckstead, IDF Value: 9.382289428951436
# Term: beckwith, IDF Value: 8.97682432084327
# Term: becky, IDF Value: 9.382289428951436
# Term: becton, IDF Value: 9.382289428951436
# Term: bedroc, IDF Value: 9.382289428951436
# Term: beech, IDF Value: 9.382289428951436
# Term: beecham, IDF Value: 8.97682432084327
# Term: beecher, IDF Value: 8.97682432084327
# Term: beef, IDF Value: 8.97682432084327
# Term: beens, IDF Value: 9.382289428951436
# Term: beer, IDF Value: 8.97682432084327
# Term: begay, IDF Value: 9.382289428951436
# Term: beggerly, IDF Value: 9.382289428951436
# Term: begier, IDF Value: 9.382289428951436
# Term: behalf, IDF Value: 7.185064851615216
# Term: behavioral, IDF Value: 9.382289428951436
# Term: beheler, IDF Value: 9.382289428951436
# Term: behrend, IDF Value: 9.382289428951436
# Term: behrens, IDF Value: 8.97682432084327
# Term: beilan, IDF Value: 9.382289428951436
# Term: bekins, IDF Value: 9.382289428951436
# Term: belcher, IDF Value: 8.97682432084327
# Term: belford, IDF Value: 9.382289428951436
# Term: belinda, IDF Value: 9.382289428951436
# Term: belknap, IDF Value: 9.382289428951436
# Term: bell, IDF Value: 6.641449405026235
# Term: bellanca, IDF Value: 9.382289428951436
# Term: bellas, IDF Value: 9.382289428951436
# Term: belle, IDF Value: 9.382289428951436
# Term: bellei, IDF Value: 9.382289428951436
# Term: bellis, IDF Value: 9.382289428951436
# Term: bellotti, IDF Value: 8.68914224839149
# Term: bellwood, IDF Value: 9.382289428951436
# Term: belmontes, IDF Value: 8.97682432084327
# Term: beloit, IDF Value: 9.382289428951436
# Term: belton, IDF Value: 9.382289428951436
# Term: beltran, IDF Value: 9.382289428951436
# Term: ben, IDF Value: 8.465998697077282
# Term: benanti, IDF Value: 9.382289428951436
# Term: benchimol, IDF Value: 9.382289428951436
# Term: bender, IDF Value: 9.382289428951436
# Term: bendix, IDF Value: 8.97682432084327
# Term: benedict, IDF Value: 8.97682432084327
# Term: benedicto, IDF Value: 9.382289428951436
# Term: beneficente, IDF Value: 9.382289428951436
# Term: beneficial, IDF Value: 8.283677140283327
# Term: beneficiary, IDF Value: 9.382289428951436
# Term: benefit, IDF Value: 7.772851516517336
# Term: benefits, IDF Value: 8.97682432084327
# Term: benguet, IDF Value: 9.382289428951436
# Term: benitez, IDF Value: 9.382289428951436
# Term: benjamin, IDF Value: 8.68914224839149
# Term: benmar, IDF Value: 9.382289428951436
# Term: bennett, IDF Value: 7.772851516517336
# Term: bennie, IDF Value: 8.68914224839149
# Term: bennis, IDF Value: 9.382289428951436
# Term: benson, IDF Value: 8.97682432084327
# Term: benten, IDF Value: 9.382289428951436
# Term: bentex, IDF Value: 9.382289428951436
# Term: benton, IDF Value: 8.97682432084327
# Term: bentsen, IDF Value: 9.382289428951436
# Term: benz, IDF Value: 8.97682432084327
# Term: berenyi, IDF Value: 9.382289428951436
# Term: berg, IDF Value: 9.382289428951436
# Term: berger, IDF Value: 8.465998697077282
# Term: bergeron, IDF Value: 8.97682432084327
# Term: bergh, IDF Value: 9.382289428951436
# Term: berghuis, IDF Value: 8.97682432084327
# Term: berkeley, IDF Value: 8.97682432084327
# Term: berkemer, IDF Value: 9.382289428951436
# Term: berkovitz, IDF Value: 9.382289428951436
# Term: berkshire, IDF Value: 9.382289428951436
# Term: berlin, IDF Value: 9.382289428951436
# Term: berman, IDF Value: 8.97682432084327
# Term: bernadine, IDF Value: 9.382289428951436
# Term: bernal, IDF Value: 8.97682432084327
# Term: bernalillo, IDF Value: 9.382289428951436
# Term: bernard, IDF Value: 8.465998697077282
# Term: bernardino, IDF Value: 9.382289428951436
# Term: berner, IDF Value: 9.382289428951436
# Term: bernhard, IDF Value: 9.382289428951436
# Term: bernhardt, IDF Value: 9.382289428951436
# Term: berra, IDF Value: 9.382289428951436
# Term: berry, IDF Value: 8.97682432084327
# Term: berryhill, IDF Value: 9.382289428951436
# Term: bershad, IDF Value: 9.382289428951436
# Term: berthold, IDF Value: 8.68914224839149
# Term: bertine, IDF Value: 9.382289428951436
# Term: bertollt, IDF Value: 9.382289428951436
# Term: bertram, IDF Value: 9.382289428951436
# Term: bess, IDF Value: 9.382289428951436
# Term: bessemer, IDF Value: 9.382289428951436
# Term: besser, IDF Value: 9.382289428951436
# Term: best, IDF Value: 8.283677140283327
# Term: bestfoods, IDF Value: 9.382289428951436
# Term: beth, IDF Value: 8.97682432084327
# Term: bethel, IDF Value: 9.382289428951436
# Term: bethenergy, IDF Value: 9.382289428951436
# Term: bethesda, IDF Value: 9.382289428951436
# Term: bethlehem, IDF Value: 9.382289428951436
# Term: beto, IDF Value: 8.68914224839149
# Term: better, IDF Value: 8.68914224839149
# Term: betterman, IDF Value: 9.382289428951436
# Term: betts, IDF Value: 9.382289428951436
# Term: betty, IDF Value: 8.283677140283327
# Term: beverage, IDF Value: 8.283677140283327
# Term: beverages, IDF Value: 9.382289428951436
# Term: bexar, IDF Value: 9.382289428951436
# Term: bfp, IDF Value: 9.382289428951436
# Term: bg, IDF Value: 9.382289428951436
# Term: bianchi, IDF Value: 9.382289428951436
# Term: biard, IDF Value: 9.382289428951436
# Term: bibb, IDF Value: 9.382289428951436
# Term: bible, IDF Value: 9.382289428951436
# Term: bibles, IDF Value: 9.382289428951436
# Term: bica, IDF Value: 9.382289428951436
# Term: bicron, IDF Value: 9.382289428951436
# Term: bies, IDF Value: 9.382289428951436
# Term: bifulco, IDF Value: 9.382289428951436
# Term: bigelow, IDF Value: 9.382289428951436
# Term: biggers, IDF Value: 8.97682432084327
# Term: biggins, IDF Value: 9.382289428951436
# Term: bilder, IDF Value: 9.382289428951436
# Term: bildisco, IDF Value: 9.382289428951436
# Term: bill, IDF Value: 7.590529959723381
# Term: billing, IDF Value: 9.382289428951436
# Term: billy, IDF Value: 8.283677140283327
# Term: bilski, IDF Value: 9.382289428951436
# Term: bindczyck, IDF Value: 9.382289428951436
# Term: binghamton, IDF Value: 9.382289428951436
# Term: bingler, IDF Value: 9.382289428951436
# Term: binks, IDF Value: 9.382289428951436
# Term: binyamin, IDF Value: 9.382289428951436
# Term: bio, IDF Value: 9.382289428951436
# Term: biosig, IDF Value: 9.382289428951436
# Term: birchfield, IDF Value: 9.382289428951436
# Term: birkdale, IDF Value: 9.382289428951436
# Term: birmingham, IDF Value: 7.772851516517336
# Term: bisceglia, IDF Value: 9.382289428951436
# Term: bisexual, IDF Value: 9.382289428951436
# Term: bishop, IDF Value: 7.9959950678315455
# Term: bisso, IDF Value: 9.382289428951436
# Term: bissonette, IDF Value: 9.382289428951436
# Term: biswell, IDF Value: 9.382289428951436
# Term: bitter, IDF Value: 9.382289428951436
# Term: bituminous, IDF Value: 9.382289428951436
# Term: bitzer, IDF Value: 9.382289428951436
# Term: bivens, IDF Value: 9.382289428951436
# Term: black, IDF Value: 7.2422232654551655
# Term: blackburn, IDF Value: 8.68914224839149
# Term: blackfeet, IDF Value: 9.382289428951436
# Term: blackledge, IDF Value: 8.97682432084327
# Term: blackmar, IDF Value: 9.382289428951436
# Term: blacksmiths, IDF Value: 9.382289428951436
# Term: blackwell, IDF Value: 9.382289428951436
# Term: blaine, IDF Value: 8.97682432084327
# Term: blair, IDF Value: 8.283677140283327
# Term: blake, IDF Value: 8.97682432084327
# Term: blakely, IDF Value: 8.97682432084327
# Term: blalock, IDF Value: 9.382289428951436
# Term: blanchard, IDF Value: 9.382289428951436
# Term: blanchette, IDF Value: 9.382289428951436
# Term: bland, IDF Value: 9.382289428951436
# Term: blanding, IDF Value: 9.382289428951436
# Term: blanton, IDF Value: 9.382289428951436
# Term: blaski, IDF Value: 9.382289428951436
# Term: blatchford, IDF Value: 9.382289428951436
# Term: blau, IDF Value: 8.68914224839149
# Term: blaze, IDF Value: 9.382289428951436
# Term: blessing, IDF Value: 9.382289428951436
# Term: blind, IDF Value: 8.68914224839149
# Term: bloate, IDF Value: 9.382289428951436
# Term: block, IDF Value: 8.465998697077282
# Term: blodgett, IDF Value: 9.382289428951436
# Term: blonder, IDF Value: 9.382289428951436
# Term: bloom, IDF Value: 9.382289428951436
# Term: bloomer, IDF Value: 9.382289428951436
# Term: bloss, IDF Value: 9.382289428951436
# Term: blount, IDF Value: 9.382289428951436
# Term: blow, IDF Value: 9.382289428951436
# Term: blowers, IDF Value: 9.382289428951436
# Term: blue, IDF Value: 7.590529959723381
# Term: bluechristine99, IDF Value: 9.382289428951436
# Term: blueford, IDF Value: 9.382289428951436
# Term: blum, IDF Value: 8.68914224839149
# Term: blumenthal, IDF Value: 8.97682432084327
# Term: blumer, IDF Value: 9.382289428951436
# Term: blumstein, IDF Value: 9.382289428951436
# Term: blystone, IDF Value: 9.382289428951436
# Term: bmw, IDF Value: 9.382289428951436
# Term: boag, IDF Value: 9.382289428951436
# Term: board, IDF Value: 4.016313413929584
# Term: boards, IDF Value: 9.382289428951436
# Term: boat, IDF Value: 9.382289428951436
# Term: boats, IDF Value: 9.382289428951436
# Term: bob, IDF Value: 7.878212032175162
# Term: bobbe, IDF Value: 9.382289428951436
# Term: bobby, IDF Value: 7.878212032175162
# Term: boberg, IDF Value: 9.382289428951436
# Term: boca, IDF Value: 8.97682432084327
# Term: bock, IDF Value: 8.97682432084327
# Term: bockting, IDF Value: 9.382289428951436
# Term: bodcaw, IDF Value: 9.382289428951436
# Term: boddie, IDF Value: 9.382289428951436
# Term: bode, IDF Value: 9.382289428951436
# Term: bodinger, IDF Value: 9.382289428951436
# Term: body, IDF Value: 9.382289428951436
# Term: boehning, IDF Value: 9.382289428951436
# Term: boeing, IDF Value: 8.68914224839149
# Term: boerckel, IDF Value: 9.382289428951436
# Term: boerne, IDF Value: 9.382289428951436
# Term: boersen, IDF Value: 9.382289428951436
# Term: boesche, IDF Value: 9.382289428951436
# Term: bogan, IDF Value: 9.382289428951436
# Term: boggs, IDF Value: 9.382289428951436
# Term: bohannan, IDF Value: 9.382289428951436
# Term: bohlen, IDF Value: 9.382289428951436
# Term: bohnen, IDF Value: 9.382289428951436
# Term: boilermakers, IDF Value: 9.382289428951436
# Term: boire, IDF Value: 9.382289428951436
# Term: boise, IDF Value: 9.382289428951436
# Term: bokulich, IDF Value: 9.382289428951436
# Term: bolden, IDF Value: 9.382289428951436
# Term: boles, IDF Value: 8.68914224839149
# Term: bolger, IDF Value: 8.97682432084327
# ...
# Term: wieman, IDF Value: 9.382289428951436
# Term: wiener, IDF Value: 9.382289428951436
# Term: wiesenfeld, IDF Value: 8.97682432084327
# Term: wiggins, IDF Value: 8.97682432084327
# Term: wigoda, IDF Value: 9.382289428951436
# Term: wilander, IDF Value: 9.382289428951436
# Term: wilbert, IDF Value: 9.382289428951436
# Term: wilbur, IDF Value: 8.97682432084327
# Term: wilburn, IDF Value: 8.97682432084327
# Term: wilcox, IDF Value: 9.382289428951436
# Term: wilde, IDF Value: 9.382289428951436
# Term: wilder, IDF Value: 9.382289428951436
# Term: wilderness, IDF Value: 8.97682432084327
# Term: wildlife, IDF Value: 8.283677140283327
# Term: wileman, IDF Value: 9.382289428951436
# Term: wiley, IDF Value: 8.68914224839149
# Term: wilkerson, IDF Value: 9.382289428951436
# Term: wilkes, IDF Value: 9.382289428951436
# Term: wilkie, IDF Value: 9.382289428951436
# Term: wilkins, IDF Value: 8.68914224839149
# Term: wilkinson, IDF Value: 8.283677140283327
# Term: wilko, IDF Value: 9.382289428951436
# Term: wilks, IDF Value: 9.382289428951436
# Term: will, IDF Value: 8.129526460456068
# Term: willard, IDF Value: 9.382289428951436
# Term: willett, IDF Value: 9.382289428951436
# Term: william, IDF Value: 5.98109204728928
# Term: williams, IDF Value: 5.98109204728928
# Term: williamsburgh, IDF Value: 9.382289428951436
# Term: williamson, IDF Value: 8.129526460456068
# Term: williamsport, IDF Value: 9.382289428951436
# Term: willie, IDF Value: 8.68914224839149
# Term: willingboro, IDF Value: 9.382289428951436
# Term: willingham, IDF Value: 9.382289428951436
# Term: willis, IDF Value: 8.68914224839149
# Term: willner, IDF Value: 9.382289428951436
# Term: willoughby, IDF Value: 9.382289428951436
# Term: willowbrook, IDF Value: 9.382289428951436
# Term: willy, IDF Value: 9.382289428951436
# Term: wilmette, IDF Value: 9.382289428951436
# Term: wilmington, IDF Value: 9.382289428951436
# Term: wilson, IDF Value: 6.939942393582231
# Term: wilton, IDF Value: 9.382289428951436
# Term: wilwording, IDF Value: 9.382289428951436
# Term: wimberly, IDF Value: 9.382289428951436
# Term: winckler, IDF Value: 9.382289428951436
# Term: winding, IDF Value: 9.382289428951436
# Term: windsor, IDF Value: 8.68914224839149
# Term: windward, IDF Value: 9.382289428951436
# Term: windy, IDF Value: 9.382289428951436
# Term: wine, IDF Value: 9.382289428951436
# Term: wingo, IDF Value: 8.97682432084327
# Term: winkelman, IDF Value: 9.382289428951436
# Term: winn, IDF Value: 8.68914224839149
# Term: winnebago, IDF Value: 9.382289428951436
# Term: winship, IDF Value: 9.382289428951436
# Term: winstar, IDF Value: 9.382289428951436
# Term: winston, IDF Value: 9.382289428951436
# Term: winter, IDF Value: 9.382289428951436
# Term: winterboer, IDF Value: 9.382289428951436
# Term: winters, IDF Value: 9.382289428951436
# Term: wintersmith, IDF Value: 9.382289428951436
# Term: wirl, IDF Value: 9.382289428951436
# Term: wirtz, IDF Value: 8.283677140283327
# Term: wisconsin, IDF Value: 6.246795213022287
# Term: wise, IDF Value: 8.97682432084327
# Term: wish, IDF Value: 9.382289428951436
# Term: wissner, IDF Value: 9.382289428951436
# Term: with, IDF Value: 9.382289428951436
# Term: witherspoon, IDF Value: 9.382289428951436
# Term: withrow, IDF Value: 8.68914224839149
# Term: witkovich, IDF Value: 9.382289428951436
# Term: witmer, IDF Value: 9.382289428951436
# Term: witsell, IDF Value: 9.382289428951436
# Term: witt, IDF Value: 9.382289428951436
# Term: witte, IDF Value: 9.382289428951436
# Term: wittek, IDF Value: 9.382289428951436
# Term: witter, IDF Value: 8.97682432084327
# Term: witters, IDF Value: 9.382289428951436
# Term: wittman, IDF Value: 9.382289428951436
# Term: wittstein, IDF Value: 9.382289428951436
# Term: wjr, IDF Value: 9.382289428951436
# Term: wmca, IDF Value: 8.465998697077282
# Term: wncn, IDF Value: 9.382289428951436
# Term: wodehouse, IDF Value: 9.382289428951436
# Term: woelke, IDF Value: 9.382289428951436
# Term: woko, IDF Value: 9.382289428951436
# Term: wolas, IDF Value: 9.382289428951436
# Term: wold, IDF Value: 8.97682432084327
# Term: wolens, IDF Value: 9.382289428951436
# Term: wolf, IDF Value: 8.68914224839149
# Term: wolfe, IDF Value: 8.97682432084327
# Term: wolff, IDF Value: 8.97682432084327
# Term: wolfish, IDF Value: 9.382289428951436
# Term: wolfsohn, IDF Value: 9.382289428951436
# Term: wolman, IDF Value: 9.382289428951436
# Term: wolston, IDF Value: 9.382289428951436
# Term: wolverine, IDF Value: 9.382289428951436
# Term: woman, IDF Value: 8.97682432084327
# Term: women, IDF Value: 7.772851516517336
# Term: wonderful, IDF Value: 9.382289428951436
# Term: wong, IDF Value: 8.129526460456068
# Term: woo, IDF Value: 9.382289428951436
# Term: wood, IDF Value: 7.3028478872716
# Term: woodall, IDF Value: 8.97682432084327
# Term: woodard, IDF Value: 8.97682432084327
# Term: woodby, IDF Value: 9.382289428951436
# Term: wooddell, IDF Value: 9.382289428951436
# Term: woodford, IDF Value: 8.68914224839149
# Term: woodlawn, IDF Value: 9.382289428951436
# Term: woodrow, IDF Value: 9.382289428951436
# Term: woods, IDF Value: 7.772851516517336
# Term: woodson, IDF Value: 8.97682432084327
# Term: woodward, IDF Value: 8.68914224839149
# Term: woodwork, IDF Value: 9.382289428951436
# Term: woody, IDF Value: 9.382289428951436
# Term: wooley, IDF Value: 9.382289428951436
# Term: woolworth, IDF Value: 8.97682432084327
# Term: wooster, IDF Value: 9.382289428951436
# Term: work, IDF Value: 9.382289428951436
# Term: workers, IDF Value: 5.52155971791084
# Term: workmen, IDF Value: 8.465998697077282
# Term: works, IDF Value: 7.590529959723381
# Term: world, IDF Value: 7.2422232654551655
# Term: worth, IDF Value: 9.382289428951436
# Term: worthington, IDF Value: 8.97682432084327
# Term: wortman, IDF Value: 9.382289428951436
# Term: worz, IDF Value: 9.382289428951436
# Term: wos, IDF Value: 9.382289428951436
# Term: wrap, IDF Value: 9.382289428951436
# Term: wrecker, IDF Value: 9.382289428951436
# Term: wrecking, IDF Value: 8.97682432084327
# Term: wrenn, IDF Value: 9.382289428951436
# Term: wright, IDF Value: 7.3028478872716
# Term: wrigley, IDF Value: 9.382289428951436
# Term: wrinkle, IDF Value: 9.382289428951436
# Term: writers, IDF Value: 8.97682432084327
# Term: wulff, IDF Value: 9.382289428951436
# Term: wunderlich, IDF Value: 9.382289428951436
# Term: wunnicke, IDF Value: 9.382289428951436
# Term: wyandotte, IDF Value: 8.97682432084327
# Term: wyatt, IDF Value: 8.97682432084327
# Term: wycoff, IDF Value: 9.382289428951436
# Term: wyeth, IDF Value: 8.97682432084327
# Term: wygant, IDF Value: 9.382289428951436
# Term: wykenna, IDF Value: 9.382289428951436
# Term: wyman, IDF Value: 7.9959950678315455
# Term: wyner, IDF Value: 9.382289428951436
# Term: wynn, IDF Value: 9.382289428951436
# Term: wynne, IDF Value: 9.382289428951436
# Term: wyoming, IDF Value: 7.367386408409171
# Term: wyrick, IDF Value: 9.382289428951436
# Term: xavier, IDF Value: 8.97682432084327
# Term: xerox, IDF Value: 9.382289428951436
# Term: yacht, IDF Value: 9.382289428951436
# Term: yahn, IDF Value: 9.382289428951436
# Term: yaka, IDF Value: 9.382289428951436
# Term: yakima, IDF Value: 8.68914224839149
# Term: yamaha, IDF Value: 9.382289428951436
# Term: yamasaki, IDF Value: 9.382289428951436
# Term: yanbu, IDF Value: 9.382289428951436
# Term: yancy, IDF Value: 9.382289428951436
# Term: yang, IDF Value: 8.97682432084327
# Term: yanira, IDF Value: 9.382289428951436
# Term: yankee, IDF Value: 9.382289428951436
# Term: yankees, IDF Value: 9.382289428951436
# Term: yankton, IDF Value: 9.382289428951436
# Term: yarborough, IDF Value: 8.97682432084327
# Term: yard, IDF Value: 9.382289428951436
# Term: yaretsky, IDF Value: 9.382289428951436
# Term: yaser, IDF Value: 9.382289428951436
# Term: yates, IDF Value: 7.9959950678315455
# Term: yazell, IDF Value: 9.382289428951436
# Term: ybarra, IDF Value: 9.382289428951436
# Term: yeager, IDF Value: 8.283677140283327
# Term: years, IDF Value: 9.382289428951436
# Term: yee, IDF Value: 8.97682432084327
# Term: yellen, IDF Value: 9.382289428951436
# Term: yellin, IDF Value: 9.382289428951436
# Term: yellow, IDF Value: 7.9959950678315455
# Term: yermian, IDF Value: 9.382289428951436
# Term: yeshiva, IDF Value: 9.382289428951436
# Term: yeskey, IDF Value: 9.382289428951436
# Term: yiatchos, IDF Value: 9.382289428951436
# Term: ylst, IDF Value: 9.382289428951436
# Term: yoder, IDF Value: 9.382289428951436
# Term: yolo, IDF Value: 9.382289428951436
# Term: yonkers, IDF Value: 8.97682432084327
# Term: york, IDF Value: 4.570105073579018
# Term: yorker, IDF Value: 9.382289428951436
# Term: yorkshire, IDF Value: 9.382289428951436
# Term: youakim, IDF Value: 8.97682432084327
# Term: young, IDF Value: 7.2422232654551655
# Term: youngberg, IDF Value: 9.382289428951436
# Term: youngblood, IDF Value: 8.68914224839149
# Term: youngdahl, IDF Value: 9.382289428951436
# Term: younger, IDF Value: 8.97682432084327
# Term: youngs, IDF Value: 9.382289428951436
# Term: youngstown, IDF Value: 8.68914224839149
# Term: yount, IDF Value: 9.382289428951436
# Term: youpee, IDF Value: 9.382289428951436
# Term: your, IDF Value: 9.382289428951436
# Term: yousuf, IDF Value: 9.382289428951436
# Term: youth, IDF Value: 9.382289428951436
# Term: ysidro, IDF Value: 9.382289428951436
# Term: ysursa, IDF Value: 9.382289428951436
# Term: yuan, IDF Value: 9.382289428951436
# Term: yuckert, IDF Value: 9.382289428951436
# Term: yueh, IDF Value: 9.382289428951436
# Term: yugoslavia, IDF Value: 9.382289428951436
# Term: yulee, IDF Value: 9.382289428951436
# Term: yums, IDF Value: 9.382289428951436
# Term: yungkau, IDF Value: 9.382289428951436
# Term: yvonne, IDF Value: 9.382289428951436
# Term: zablocki, IDF Value: 9.382289428951436
# Term: zacarias, IDF Value: 9.382289428951436
# Term: zacchini, IDF Value: 9.382289428951436
# Term: zachry, IDF Value: 9.382289428951436
# Term: zacks, IDF Value: 9.382289428951436
# Term: zadvydas, IDF Value: 9.382289428951436
# Term: zafiro, IDF Value: 9.382289428951436
# Term: zahn, IDF Value: 9.382289428951436
# Term: zakhar, IDF Value: 9.382289428951436
# Term: zandford, IDF Value: 9.382289428951436
# Term: zant, IDF Value: 7.878212032175162
# Term: zapata, IDF Value: 9.382289428951436
# Term: zatko, IDF Value: 9.382289428951436
# Term: zauderer, IDF Value: 9.382289428951436
# Term: zavada, IDF Value: 9.382289428951436
# Term: zazove, IDF Value: 9.382289428951436
# Term: zbaraz, IDF Value: 8.97682432084327
# Term: zdanok, IDF Value: 9.382289428951436
# Term: zebley, IDF Value: 9.382289428951436
# Term: zedner, IDF Value: 9.382289428951436
# Term: zeitz, IDF Value: 9.382289428951436
# Term: zell, IDF Value: 8.97682432084327
# Term: zelman, IDF Value: 9.382289428951436
# Term: zemel, IDF Value: 9.382289428951436
# Term: zenith, IDF Value: 8.465998697077282
# Term: zicarelli, IDF Value: 9.382289428951436
# Term: zicherman, IDF Value: 9.382289428951436
# Term: zikee, IDF Value: 9.382289428951436
# Term: zimmerman, IDF Value: 9.382289428951436
# Term: zimmermann, IDF Value: 9.382289428951436
# Term: zimring, IDF Value: 9.382289428951436
# Term: zinermon, IDF Value: 9.382289428951436
# Term: zipes, IDF Value: 8.97682432084327
# Term: zipkin, IDF Value: 9.382289428951436
# Term: zittman, IDF Value: 8.97682432084327
# Term: zivotofsky, IDF Value: 8.97682432084327
# Term: ziya, IDF Value: 9.382289428951436
# Term: zobel, IDF Value: 9.382289428951436
# Term: zobrest, IDF Value: 9.382289428951436
# Term: zolin, IDF Value: 8.97682432084327
# Term: zook, IDF Value: 9.382289428951436
# Term: zorach, IDF Value: 9.382289428951436
# Term: zschernig, IDF Value: 9.382289428951436
# Term: zuber, IDF Value: 9.382289428951436
# Term: zubik, IDF Value: 9.382289428951436
# Term: zucca, IDF Value: 9.382289428951436
# Term: zuckerman, IDF Value: 9.382289428951436
# Term: zuckert, IDF Value: 9.382289428951436
# Term: zuni, IDF Value: 9.382289428951436
# Term: zurcher, IDF Value: 9.382289428951436
# Term: zurich, IDF Value: 8.97682432084327
# Term: zurko, IDF Value: 9.382289428951436
# Term: zwicker, IDF Value: 9.382289428951436
# Term: zwickler, IDF Value: 8.97682432084327
# Term: zzzz, IDF Value: 9.382289428951436
# <bound method TfidfVectorizer.fit of TfidfVectorizer()>
# ['011', '10', '100', '1000', '1001', '1029', '103', '104', '107', '11', '112', '114', '1182', '12', '1212', '1229', '125', '1263', '1264', '128', '1285', '1287', '1291', '13', '1309', '1315', '134', '14', '1416', '1424', '144', '149', '15', '150', '153', '16', '1625', '17', '174', '1784', '1802', '187', '189', '1958', '1976', '20', '200', '203', '205', '207', '23', '232', '24', '25', '255', '26', '262', '26th', '28', '283', '298', '30', '309', '30th', '31st', '324', '33', '334', '338', '340', '347', '3489', '355', '357', '358', '37', '391', '40', '403', '405', '419', '427', '438', '44', '449', '473', '476', '47j', '480', '496', '50', '54', '562', '564', '585', '590', '60', '610', '62', '627', '633', '638', '639', '641', '65', '660', '6799', '680', '695', '70', '71', '718', '721', '727', '735', '74', '751', '759', '76', '760', '761', '770', '771', '776', '787', '79', '790', '795', '82', '825', '850', '89', '8mm', '91', '92', '926', '93', '94', '95', '970', '998', 'aa', 'aaron', 'abate', 'abatement', 'abbate', 'abbott', 'abc', 'abdi', 'abdu', 'abdul', 'abdullah', 'abdur', 'abdus', 'abel', 'abend', 'abercrombie', 'aberdeen', 'abernathy', 'abf', 'abid', 'abigail', 'abington', 'abner', 'abney', 'abood', 'abortion', 'abourezk', 'abraham', 'abrahamson', 'abram', 'abrams', 'abramski', 'abramson', 'abrasive', 'abu', 'abudu', 'abuelhawa', 'academic', 'academy', 'acb', 'accardi', 'acceptance', 'accident', 'accountancy', 'accounting', 'accounts', 'ace', 'acevedo', 'acf', 'acheson', 'achilli', 'acker', 'ackerman', 'ackermann', 'acme', 'acosta', 'acquisition', 'acres', 'acri', 'actavis', 'acting', 'action', 'activities', 'acton', 'actors', 'acuff', 'ad', 'ada', 'adam', 'adamo', 'adams', 'adamson', 'adarand', 'aday', 'adderley', 'addington', 'addition', 'addonizio', 'adelaide', 'adickes', 'adjustment', 'adkins', 'adler', 'admininistrator', 'administration', 'administrator', 'administrators', 'administratrator', 'administratrix', 'admissions', 'adoptive', 'adrian', 'adult', 'advanced', 'advancement', 'advantage', 'advertising', 'advisors', 'advisory', 'advocacy', 'aerea', 'aeree', 'aereo', 'aero', 'aerojet', 'aeronautical', 'aeronautics', 'aerospace', 'aerospatiale', 'aetna', 'affairs', 'affiliated', 'affiliates', 'affirmative', 'affolder', 'affronti', 'afl', 'aflcio', 'afroyim', 'aft', 'afton', 'ag', 'against', 'agard', 'agee', 'agencies', 'agency', 'agent', 'agents', 'agins', 'agnew', 'agostini', 'agosto', 'agricultural', 'agriculture', 'agron', 'agrosciences', 'aguilar', 'aguillard', 'aguirre', 'agurs', 'agyei', 'ahern', 'ahlborn', 'ahlers', 'ahmed', 'ahrens', 'aid', 'aids', 'aiello', 'aiken', 'aikens', 'air', 'aircraft', 'airline', 'airlines', 'airport', 'airports', 'airways', 'aka', 'akamai', 'ake', 'akins', 'akio', 'akos', 'akron', 'aktiebolaget', 'aktiengesellschaft', 'al', 'ala', 'alabama', 'aladdin', 'alafabco', 'alameda', 'alamo', 'alan', 'alaska', 'albanese', 'albemarle', 'albernaz', 'albers', 'albert', 'alberta', 'albertini', 'alberto', 'albertson', 'albrecht', 'albright', 'alcala', 'alcan', 'alcea', 'alco', 'alcoa', 'alcohol', 'alcoholic', 'alcorta', 'alden', 'alderman', 'aldinger', 'aldona', 'aldrich', 'alejandra', 'alejandro', 'alene', 'alessi', 'aletha', 'alex', 'alexander', 'alexandre', 'alexandria', 'alexis', 'alfalfa', 'alfonso', 'alfonzo', 'alford', 'alfred', 'algoma', 'algonquin', 'ali', 'alias', 'alice', 'alicia', 'alida', 'alien', 'alison', 'alitalia', 'alkali', 'all', 'allain', 'allan', 'allapattah', 'allard', 'allcare', 'allee', 'alleghany', 'allegheny', 'allen', 'allenberg', 'allentown', 'alleyne', 'alliance', 'allianz', 'allied', 'allis', 'allison', 'alloyd', 'allstate', 'alma', 'almeida', 'almendarez', 'almota', 'aloha', 'alonzo', 'aloyzas', 'alpers', 'alpert', 'alphonso', 'alpine', 'already', 'also', 'alstate', 'althon', 'altmann', 'alto', 'alton', 'altria', 'aluminium', 'aluminum', 'alvarado', 'alvarez', 'alvez', 'alvin', 'alyeska', 'am', 'amadeo', 'amalgamated', 'amanda', 'amant', 'amara', 'amarillo', 'amax', 'a ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
#  Removing Punctuation,
#  Spaces,
#  Sentence Segment
#  and turning into list

# %%
def PreProcess(Text):
    # Remove punctuation, spaces, and unwanted characters
    Rule = re.compile(r'[^a-zA-Z0-9\u4e00-\u9fa5]')
    Text = Rule.sub(' ', str(Text))
    Text = re.sub(' +', ' ', Text)

    # Split the text into words (tokenization) and return as a list
    Text = Text.split()  # Split text into words based on spaces

    return Text

# %% [markdown]
# # Implementing Word2Vec

# %%
# Implementing Data Sclicing Procedure With Respect To 1000 Samples
SubsetSize = 1000  
SubsetData = Data.head(SubsetSize).copy()  

# Training the Word2Vec model on the basis of the corresponding subset
SubsetSentences = SubsetData['case_name'].tolist()
SubsetSentences = [PreProcess(text) for text in SubsetSentences]

Model = Word2Vec(
    SubsetSentences,
    vector_size=100,
    window=5,
    min_count=1,
    sg=0
)

# Incorporating TF-IDF information into Word2Vec word vectors
for Word in Model.wv.index_to_key:
    WordVector = Model.wv[Word]
    if Word in Dictionary:
        TFIDFWeight = Dictionary[Word]
        WeightedVector = WordVector * TFIDFWeight
        Model.wv[Word] = WeightedVector

# Saving the Word2Vec model
Model.save("word2vec_with_tfidf_1000samples.model")
# Printing the data details
print(len(Data))
print(len(SubsetSentences))

# Loading the Word2Vec model with TF-IDF weighting
Word2VecModel = Word2Vec.load("word2vec_with_tfidf_1000samples.model")
# Out:
# 8737
# 1000

# %%
# Implementing recommendation engine 
def recommend_law(Text, Data, model=Word2VecModel):
    # Tokenizing and preprocessing the input text
    Text = PreProcess(Text)

    # Initializing variables to store Similarities and recommended laws
    Similarities = []
    RecommendedLaws = []

    for _, row in Data.iterrows():
        # Tokenizing and preprocessing the legal texts in your dataset
        LegalText = PreProcess(row['case_name'])

        # Calculating the Similarity between the input text and legal text
        Similarity = 0  # Initializing Similarity score to 0
        Count = 0  # Initializing a Count to keep track of common words

        for Word in Text:
            if Word in model.wv and Word in LegalText:
                Similarity += model.wv.n_similarity([Word], LegalText)
                Count += 1

        if Count > 0:
            Similarity /= Count  # Calculating the Average Similarity scores

        # Saving the Similarity score and corresponding legal text
        Similarities.append(Similarity)
        RecommendedLaws.append(row['case_name'])

    # Combining the Similarities and recommended laws into a DataFrame
    Recommendationdf = pd.DataFrame({'Legal Text': RecommendedLaws, 'Similarity': Similarities})

    # Sorting the DataFrame by Similarity in descending order
    Recommendationdf = Recommendationdf.sort_values(by='Similarity', ascending=False)

    # Returning the top recommended laws
    TopRecommendations = Recommendationdf.head(20)

    return TopRecommendations

# %%
# Printing the Recommendations with respect to graphical representation of similarity ratio
def plot_recommendations(Recommendations):
    # Plotting
    Plot.figure(figsize=(10, 6))
    Plot.barh(Recommendations['Legal Text'], Recommendations['Similarity'], color='orange')
    Plot.xlabel('Similarity Score')
    Plot.title('Top 20 Recommended Laws')
    Plot.gca().invert_yaxis()  # Inverting y-axis to calculating the highest similarity at the top
    Plot.show()

# Experimenting by entering input text
InputText = "United States"
TopRecommendations = recommend_law(InputText, Data, model=Word2VecModel)
plot_recommendations(TopRecommendations)

# %%
# Calculating Mean Similarity Score with respect to recommendations
MeanSimilarity = TopRecommendations['Similarity'].mean()
print(f"Mean Similarity Score: {MeanSimilarity}")

# Displaying a histogram of similarity scores with respect to recommendations
Plot.hist(TopRecommendations['Similarity'], bins=20)
Plot.xlabel('Similarity Score')
Plot.ylabel('Frequency')
Plot.title('Distribution of Similarity Scores')
Plot.show()

# Displaying a histogram of Density of similarity scores with respect to recommendations
sns.histplot(TopRecommendations['Similarity'], kde=True)
Plot.xlabel('Similarity Score')
Plot.ylabel('Density')
Plot.title('Density Plot of Similarity Scores')
Plot.show()
# Out:
# Mean Similarity Score: 0.0

# %% [markdown]
# Results of Implementation of Word2Vec Model With respect to 1000 samples

# %%
def plot_recommendations(Recommendations):
    # Plotting recommendations
    fig, axes = Plot.subplots(nrows=2, ncols=2, figsize=(12, 10))

    # Plotting the bar plot for recommendations
    Axes1 = axes[0, 0]
    Axes1.barh(Recommendations['Legal Text'], Recommendations['Similarity'], color='orange')
    Axes1.set_xlabel('Similarity Score')
    Axes1.set_title('Top 20 Recommended Laws')
    Axes1.invert_yaxis()

    # Calculating mean similarity
    MeanSimilarity = Recommendations['Similarity'].mean()

    # Plotting the histogram
    Axes2 = axes[0, 1]
    Axes2.hist(Recommendations['Similarity'], bins=20)
    Axes2.set_xlabel('Similarity Score')
    Axes2.set_ylabel('Frequency')
    Axes2.set_title('Distribution of Similarity Scores')
    Axes2.axvline(MeanSimilarity, color='red', linestyle='dashed', linewidth=1, label=f"Mean: {MeanSimilarity:.2f}")
    Axes2.legend()

    # Plotting the density plot
    Axes3 = axes[1, 0:2]
    sns.histplot(Recommendations['Similarity'], kde=True, ax=Axes3[0])
    Axes3[0].set_xlabel('Similarity Score')
    Axes3[0].set_ylabel('Density')
    Axes3[0].set_title('Density Plot of Similarity Scores')

    Plot.tight_layout()
    Plot.show()

InputText = "United States"
TopRecommendations = recommend_law(InputText, Data, model=Word2VecModel)
plot_recommendations(TopRecommendations)

# %% [markdown]
# # Implementing BERT

# %%
# Implementing Data Sclicing Procedure With Respect To 1000 Samples
SubsetSize = 1000 

SmallerSubset = Data.head(SubsetSize).copy() 

Corpus = SmallerSubset['case_name'].tolist()

# Preprocessing the corpus and feature names for TF-IDF
Corpus = [text.lower() for text in Corpus]  # Converting text to lowercase for consistency

# Initializing a BERT tokenizer and model
Tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
BertModel = BertModel.from_pretrained('bert-base-uncased')

# Tokenizing and getting BERT embeddings in smaller batches
BatchSize = 32 
MaxLength = 128 
EmbeddingsList = []


# Implementing the Helper function for processing a batch and for obtaining BERT embeddings
def process_batch(BatchTexts):
    # Preprocessing batch texts to lowercase
    BatchTexts = [text.lower() for text in BatchTexts]

    inputs = Tokenizer(
        BatchTexts,
        return_tensors='pt',
        padding='max_length',  
        max_length=MaxLength,  
        truncation=True
    )
    with torch.no_grad():
        BatchEmbeddings = BertModel(**inputs).last_hidden_state

    return BatchEmbeddings


for i in range(0, len(Corpus), BatchSize):
    BatchTexts = Corpus[i:i + BatchSize]
    BatchEmbeddings = process_batch(BatchTexts)
    EmbeddingsList.append(BatchEmbeddings)

# Concatenating embeddings from different batches for the smaller subset
Embeddings = torch.cat(EmbeddingsList, dim=0)

# Printing the data details
print(len(Data))
print(len(Embeddings))
# Out:
# 8737
# 1000

# %%
# Implementing recommendation engine 
def recommend_law(Text, Data, Embeddings):
    Similarities = []
    RecommendedLaws = []
    AverageSimilarities = []

    # Tokenizing and preprocessing the input text
    Text = Text.lower()
    inputs1 = Tokenizer(
        [Text],
        return_tensors='pt',
        padding='max_length',
        max_length=MaxLength,
        truncation=True
    )
    with torch.no_grad():
        Embeddings1 = BertModel(**inputs1).last_hidden_state

    for i in range(len(Embeddings)):
        LegalText = Data['case_name'].iloc[i].lower()
        inputs2 = Tokenizer(
            [LegalText],
            return_tensors='pt',
            padding='max_length',
            max_length=MaxLength,
            truncation=True
        )
        with torch.no_grad():
            Embeddings2 = Embeddings[i]  # Utilizing the precomputed DeBERTa embeddings for the smaller subset

        # Calculating cosine similarity between embeddings
        similarity = torch.nn.functional.cosine_similarity(Embeddings1, Embeddings2, dim=1).max().item()

        Similarities.append(similarity)
        RecommendedLaws.append(Data['case_name'].iloc[i])
        # Calculating average similarity for each interaction
        AverageSimilarity = np.mean(Similarities)
        AverageSimilarities.append(AverageSimilarity)
    Recommendationdf = pd.DataFrame({'Legal Text': RecommendedLaws, 'Similarity1': Similarities})
    Recommendationdf = Recommendationdf.sort_values(by='Similarity1', ascending=False)
    TopRecommendations = Recommendationdf.head(20)

    return TopRecommendations, AverageSimilarities

# %%
# Printing the Recommendations with respect to graphical representation of similarity ratio
def plot_recommendations(Recommendations):
    # Plotting
    Plot.figure(figsize=(10, 6))
    Plot.barh(Recommendations[0]['Legal Text'], Recommendations[0]['Similarity1'], color='blue')
    Plot.xlabel('Similarity Score')
    Plot.title('Top 20 Recommended Citations')
    Plot.gca().invert_yaxis()  # Inverting y-axis to have the highest similarity at the top
    Plot.show()

# Experimenting by entering input text
InputText = "United States"
TopRecommendations = recommend_law(InputText, Data, Embeddings)
plot_recommendations(TopRecommendations)

# %%
# Representating Average Similarity Scores With Respect to 1000 Iteractions
TopRecommendations, AvgSimilarities = recommend_law(InputText, SmallerSubset, Embeddings)

# Converting smaller_subset to numpy array or list
SmallerSubsetArray = SmallerSubset['case_name'].values.tolist()

# Plotting convergence metrics
Interactions = np.arange(1, len(AvgSimilarities) + 1)
Plot.figure(figsize=(8, 5))
Plot.plot(Interactions, AvgSimilarities, color='green')
Plot.title('Convergence: Average Similarity over Interactions')
Plot.xlabel('Number of Interactions')
Plot.ylabel('Average Similarity')
Plot.grid(True)
Plot.show()

# %%
# Calculating Mean Similarity Score with respect to recommendations
MeanSimilarity = TopRecommendations['Similarity1'].mean()
print(f"Mean Similarity Score: {MeanSimilarity}")

# Displaying a histogram of similarity scores
Plot.hist(TopRecommendations['Similarity1'], bins=20)
Plot.xlabel('Similarity Score')
Plot.ylabel('Frequency')
Plot.title('Distribution of Similarity Scores')
Plot.show()

# Displaying a histogram of Density of similarity scores with respect to recommendations
sns.histplot(TopRecommendations['Similarity1'], kde=True)
Plot.xlabel('Similarity Score')
Plot.ylabel('Density')
Plot.title('Density Plot of Similarity Scores')
Plot.show()
# Out:
# Mean Similarity Score: 6.936242198944091

# %% [markdown]
# Results of Implementation of BERT Model With respect to 1000 samples

# %%
def plot_recommendations(Recommendations):
    # Unpacking the tuple of recommendations and average similarities
    TopRecommendations, AvgSimilarities = Recommendations

    # Creating a 2x2 grid of subplots
    fig, axes = Plot.subplots(2, 2, figsize=(15, 12))

    # Plotting the bar plot for recommendations
    Axes1 = axes[0, 0]
    Axes1.barh(TopRecommendations['Legal Text'], TopRecommendations['Similarity1'], color='blue')
    Axes1.set_xlabel('Similarity Score')
    Axes1.set_title('Top 20 Recommended Citations')

    # Plotting the convergence metrics
    Axes2 = axes[0, 1]
    interactions = range(1, len(AvgSimilarities) + 1)
    Axes2.plot(interactions, AvgSimilarities, color='green')
    Axes2.set_title('Convergence: Average Similarity over Interactions')
    Axes2.set_xlabel('Number of Interactions')
    Axes2.set_ylabel('Average Similarity')
    Axes2.grid(True)

    # Plotting the histogram of similarity scores
    Axes3 = axes[1, 0]
    Axes3.hist(TopRecommendations['Similarity1'], bins=20)
    Axes3.set_xlabel('Similarity Score')
    Axes3.set_ylabel('Frequency')
    Axes3.set_title('Distribution of Similarity Scores')

    # Plotting the density plot of similarity scores
    Axes4 = axes[1, 1]
    sns.histplot(TopRecommendations['Similarity1'], kde=True, ax=Axes4)
    Axes4.set_xlabel('Similarity Score')
    Axes4.set_ylabel('Density')
    Axes4.set_title('Density Plot of Similarity Scores')

    # Adjusting layout and displaying plots
    Plot.tight_layout()
    Plot.show()

InputText = "United States"
TopRecommendations, AvgSimilarities = recommend_law(InputText, Data, Embeddings)
plot_recommendations((TopRecommendations, AvgSimilarities))

# %% [markdown]
# # Implementing ALBERT

# %%
# Implementing Data Sclicing Procedure With Respect To 1000 Samples

SubsetSize = 1000  

SmallerSubset = Data.head(SubsetSize).copy()  

Corpus = SmallerSubset['case_name'].tolist()

# Preprocessing the corpus for TF-IDF
Corpus = [text.lower() for text in Corpus]  # Convert text to lowercase for consistency

# Initializing an ALBERT tokenizer and model
Tokenizer = AlbertTokenizer.from_pretrained('albert-base-v2')
AlbertModel = AlbertModel.from_pretrained('albert-base-v2')

# Tokenizing and getting ALBERT embeddings in smaller batches
BatchSize = 32  # You can adjust this as needed
MaxLength = 128  # You can adjust this as needed
EmbeddingsList = []


# Implementing Helper function to process a batch and obtain ALBERT embeddings
def process_batch(BatchTexts):
    # Preprocessing batch texts to lowercase
    BatchTexts = [text.lower() for text in BatchTexts]

    inputs = Tokenizer(
        BatchTexts,
        return_tensors='pt',
        padding='max_length', 
        max_length=MaxLength,  
        truncation=True
    )
    with torch.no_grad():
        BatchOutputs = AlbertModel(**inputs)
        BatchEmbeddings = BatchOutputs.last_hidden_state

    return BatchEmbeddings


for i in range(0, len(Corpus), BatchSize):
    BatchTexts = Corpus[i:i + BatchSize]
    BatchEmbeddings = process_batch(BatchTexts)
    EmbeddingsList.append(BatchEmbeddings)

# Concatenating embeddings from different batches for the smaller subset
Embeddings = torch.cat(EmbeddingsList, dim=0)

# Printing the data details
print(len(Data))
print(len(Embeddings))
# Out:
# 8737
# 1000

# %%
# Implementing recommendation engine 
def Recommend_Laws(Text, Data, Embeddings):
    Similarities = []
    RecommendedLaws = []
    AverageSimilarities = []

    # Tokenizing and preprocess the input text
    Text = Text.lower()
    inputs1 = Tokenizer(
        [Text],
        return_tensors='pt',
        padding='max_length',
        max_length=MaxLength,
        truncation=True
    )
    with torch.no_grad():
        Embeddings1 = AlbertModel(**inputs1).last_hidden_state

    for i in range(len(Embeddings)):
        LegalText = Data['case_name'].iloc[i].lower()
        inputs2 = Tokenizer(
            [LegalText],
            return_tensors='pt',
            padding='max_length',
            max_length=MaxLength,
            truncation=True
        )
        with torch.no_grad():
            Embeddings2 = Embeddings[i]  # Use the precomputed DeBERTa embeddings for the smaller subset

        # Calculating cosine similarity between embeddings
        Similarity = torch.nn.functional.cosine_similarity(Embeddings1, Embeddings2, dim=1).max().item()

        Similarities.append(Similarity)
        RecommendedLaws.append(Data['case_name'].iloc[i])
        # Calculating average similarity for each interaction
        AverageSimilarity = np.mean(Similarities)
        AverageSimilarities.append(AverageSimilarity)
    Recommendationdf = pd.DataFrame({'Legal Text': RecommendedLaws, 'Similarity2': Similarities})
    Recommendationdf = Recommendationdf.sort_values(by='Similarity2', ascending=False)
    TopRecommendations = Recommendationdf.head(20)

    return TopRecommendations, AverageSimilarities

# %%
# Printing the Recommendations with respect to graphical representation of similarity ratio
def plot_recommendations(Recommendations):
    # Plotting
    Plot.figure(figsize=(10, 6))
    Plot.barh(Recommendations[0]['Legal Text'], Recommendations[0]['Similarity2'], color='green')
    Plot.xlabel('Similarity Score')
    Plot.title('Top 20 Recommended Citations')
    Plot.gca().invert_yaxis()  # Inverting y-axis to have the highest similarity at the top
    Plot.show()

# Experimenting by entering input text
InputText = "United States"
TopRecommendations = Recommend_Laws(InputText, Data, Embeddings)
plot_recommendations(TopRecommendations)

# %%
# Representating Average Similarity Scores With Respect to 1000 Iteractions
TopRecommendations, AvgSimilarities = Recommend_Laws(InputText, SmallerSubset, Embeddings)

# Converting smaller_subset to numpy array or list
SmallerSubsetArray = SmallerSubset['case_name'].values.tolist()

# Plotting convergence metrics
Interactions = np.arange(1, len(AvgSimilarities) + 1)
Plot.figure(figsize=(8, 5))
Plot.plot(Interactions, AvgSimilarities, color='red')
Plot.title('Convergence: Average Similarity over Interactions')
Plot.xlabel('Number of Interactions')
Plot.ylabel('Average Similarity')
Plot.grid(True)
Plot.show()

# %%
# Calculating Mean Similarity Score with respect to recommendations
MeanSimilarity = TopRecommendations['Similarity2'].mean()
print(f"Mean Similarity Score: {MeanSimilarity}")

# Displaying a histogram of similarity scores
Plot.hist(TopRecommendations['Similarity2'], bins=20)
Plot.xlabel('Similarity Score')
Plot.ylabel('Frequency')
Plot.title('Distribution of Similarity Scores')
Plot.show()

# Displaying a histogram of Density of similarity scores with respect to recommendations
sns.histplot(TopRecommendations['Similarity2'], kde=True)
Plot.xlabel('Similarity Score')
Plot.ylabel('Density')
Plot.title('Density Plot of Similarity Scores')
Plot.show()
# Out:
# Mean Similarity Score: 7.9408657312393185

# %% [markdown]
# Results of Implementation of ALBERT Model With respect to 1000 samples

# %%
def plot_recommendations(Recommendations):
    # Unpacking the tuple of recommendations and average similarities
    TopRecommendations, AvgSimilarities = Recommendations

    # Creating a 2x2 grid of subplots
    fig, axes = Plot.subplots(2, 2, figsize=(15, 12))

    # Plotting the bar plot for recommendations
    Axes1 = axes[0, 0]
    Axes1.barh(TopRecommendations['Legal Text'], TopRecommendations['Similarity2'], color='green')
    Axes1.set_xlabel('Similarity Score')
    Axes1.set_title('Top 20 Recommended Citations')

    # Plotting the convergence metrics
    Axes2 = axes[0, 1]
    interactions = range(1, len(AvgSimilarities) + 1)
    Axes2.plot(interactions, AvgSimilarities, color='red')
    Axes2.set_title('Convergence: Average Similarity over Interactions')
    Axes2.set_xlabel('Number of Interactions')
    Axes2.set_ylabel('Average Similarity')
    Axes2.grid(True)

    # Plotting the histogram of similarity scores
    Axes3 = axes[1, 0]
    Axes3.hist(TopRecommendations['Similarity2'], bins=20)
    Axes3.set_xlabel('Similarity Score')
    Axes3.set_ylabel('Frequency')
    Axes3.set_title('Distribution of Similarity Scores')

    # Plotting the density plot of similarity scores
    Axes4 = axes[1, 1]
    sns.histplot(TopRecommendations['Similarity2'], kde=True, ax=Axes4)
    Axes4.set_xlabel('Similarity Score')
    Axes4.set_ylabel('Density')
    Axes4.set_title('Density Plot of Similarity Scores')

    # Adjusting layout and display plots
    Plot.tight_layout()
    Plot.show()

InputText = "United States"
TopRecommendations, AvgSimilarities = Recommend_Laws(InputText, Data, Embeddings)
plot_recommendations((TopRecommendations, AvgSimilarities))

# %% [markdown]
# # Implementing DeBERTa

# %%
# Implementing Data Sclicing Procedure With Respect To 1000 Samples

SubsetSize = 1000  

SmallerSubset = Data.head(SubsetSize).copy() 

Corpus = SmallerSubset['case_name'].tolist()

# Preprocessing the corpus for TF-IDF
Corpus = [text.lower() for text in Corpus]  # Convert text to lowercase for consistency

# Initializing a DeBERTa tokenizer and model
Tokenizer = DebertaTokenizer.from_pretrained('microsoft/deberta-base')
DebertaModel = DebertaModel.from_pretrained('microsoft/deberta-base')

# Tokenizing and getting DeBERTa embeddings in smaller batches
BatchSize = 32  # You can adjust this as needed
MaxLength = 128  # You can adjust this as needed
EmbeddingsList = []


# Implementing Helper function to process a batch and obtain DeBERTa embeddings
def process_batch(BatchTexts):
    # Preprocessing batch texts to lowercase
    BatchTexts = [text.lower() for text in BatchTexts]

    inputs = Tokenizer(
        BatchTexts,
        return_tensors='pt',
        padding='max_length',  
        max_length=MaxLength,  
        truncation=True
    )
    with torch.no_grad():
        BatchOutputs = DebertaModel(**inputs)
        BatchEmbeddings = BatchOutputs.last_hidden_state

    return BatchEmbeddings


for i in range(0, len(Corpus), BatchSize):
    BatchTexts = Corpus[i:i + BatchSize]
    BatchEmbeddings = process_batch(BatchTexts)
    EmbeddingsList.append(BatchEmbeddings)

# Concatenating embeddings from different batches for the smaller subset
Embeddings = torch.cat(EmbeddingsList, dim=0)

# Printing the data details
print(len(Data))
print(len(Embeddings))
# Out:
# 8737
# 1000

# %%
# Implementing recommendation engine 
def RecommendLaw(Text, Data, Embeddings):
    Similarities = []
    RecommendedLaws = []
    AverageSimilarities = []

    # Tokenizing and preprocessing the input text
    Text = Text.lower()
    inputs1 = Tokenizer(
        [Text],
        return_tensors='pt',
        padding='max_length',
        max_length=MaxLength,
        truncation=True
    )
    with torch.no_grad():
        Embeddings1 = DebertaModel(**inputs1).last_hidden_state

    for i in range(len(Embeddings)):
        LegalText = Data['case_name'].iloc[i].lower()
        inputs2 = Tokenizer(
            [LegalText],
            return_tensors='pt',
            padding='max_length',
            max_length=MaxLength,
            truncation=True
        )
        with torch.no_grad():
            Embeddings2 = Embeddings[i]  # Utilizing the precomputed DeBERTa embeddings for the smaller subset

        # Calculating cosine similarity between embeddings
        Similarity = torch.nn.functional.cosine_similarity(Embeddings1, Embeddings2, dim=1).max().item()

        Similarities.append(Similarity)
        RecommendedLaws.append(Data['case_name'].iloc[i])
        # Calculating average similarity for each interaction
        AverageSimilarity = np.mean(Similarities)
        AverageSimilarities.append(AverageSimilarity)
    Recommendationdf = pd.DataFrame({'Legal Text': RecommendedLaws, 'Similarity3': Similarities})
    Recommendationdf = Recommendationdf.sort_values(by='Similarity3', ascending=False)
    TopRecommendations = Recommendationdf.head(20)

    return TopRecommendations, AverageSimilarities

# %%
# Printing the Recommendations with respect to graphical representation of similarity ratio
def plot_recommendations(Recommendations):
    # Plotting
    Plot.figure(figsize=(10, 6))
    Plot.barh(Recommendations[0]['Legal Text'], Recommendations[0]['Similarity3'], color='red')
    Plot.xlabel('Similarity Score')
    Plot.title('Top 20 Recommended Citations')
    Plot.gca().invert_yaxis()  # Inverting y-axis to have the highest similarity at the top
    Plot.show()

# Experimenting by entering input text
InputText = "United States"
TopRecommendations = RecommendLaw(InputText, Data, Embeddings)
plot_recommendations(TopRecommendations)

# %%
# Representating Average Similarity Scores With Respect to 1000 Iteractions
TopRecommendations, AvgSimilarities = RecommendLaw(InputText, SmallerSubset, Embeddings)

# Converting smaller_subset to numpy array or list
SmallerSubsetArray = SmallerSubset['case_name'].values.tolist()

# Plotting convergence metrics
Interactions = np.arange(1, len(AvgSimilarities) + 1)
Plot.figure(figsize=(8, 5))
Plot.plot(Interactions, AvgSimilarities, color='blue')
Plot.title('Convergence: Average Similarity over Interactions')
Plot.xlabel('Number of Interactions')
Plot.ylabel('Average Similarity')
Plot.grid(True)
Plot.show()

# %%
# Calculating Mean Similarity Score with respect to recommendations
MeanSimilarity = TopRecommendations['Similarity3'].mean()
print(f"Mean Similarity Score: {MeanSimilarity}")

# Displaying a histogram of similarity scores
Plot.hist(TopRecommendations['Similarity3'], bins=20)
Plot.xlabel('Similarity Score')
Plot.ylabel('Frequency')
Plot.title('Distribution of Similarity Scores')
Plot.show()

# Displaying a histogram of Density of similarity scores with respect to recommendations
sns.histplot(TopRecommendations['Similarity3'], kde=True)
Plot.xlabel('Similarity Score')
Plot.ylabel('Density')
Plot.title('Density Plot of Similarity Scores')
Plot.show()
# Out:
# Mean Similarity Score: 8.867090034484864

# %% [markdown]
# Results of Implementation of DeBERTa Model With respect to 1000 samples

# %%
def Plot_Recommendations(Recommendations):
    # Unpacking the tuple of recommendations and average similarities
    TopRecommendations, AvgSimilarities = Recommendations

    # Creating a 2x2 grid of subplots
    fig, axes = Plot.subplots(2, 2, figsize=(15, 12))

    # Plotting the bar plot for recommendations
    Axes1 = axes[0, 0]
    Axes1.barh(TopRecommendations['Legal Text'], TopRecommendations['Similarity3'], color='red')
    Axes1.set_xlabel('Similarity Score')
    Axes1.set_title('Top 20 Recommended Citations')

    # Plotting the convergence metrics
    Axes2 = axes[0, 1]
    interactions = range(1, len(AvgSimilarities) + 1)
    Axes2.plot(interactions, AvgSimilarities, color='blue')
    Axes2.set_title('Convergence: Average Similarity over Interactions')
    Axes2.set_xlabel('Number of Interactions')
    Axes2.set_ylabel('Average Similarity')
    Axes2.grid(True)

    # Plotting the histogram of similarity scores
    Axes3 = axes[1, 0]
    Axes3.hist(TopRecommendations['Similarity3'], bins=20)
    Axes3.set_xlabel('Similarity Score')
    Axes3.set_ylabel('Frequency')
    Axes3.set_title('Distribution of Similarity Scores')

    # Plotting the density plot of similarity scores
    Axes4 = axes[1, 1]
    sns.histplot(TopRecommendations['Similarity3'], kde=True, ax=Axes4)
    Axes4.set_xlabel('Similarity Score')
    Axes4.set_ylabel('Density')
    Axes4.set_title('Density Plot of Similarity Scores')

    # Adjusting layout and display plots
    Plot.tight_layout()
    Plot.show()

InputText = "United States"
TopRecommendations, AvgSimilarities = RecommendLaw(InputText, Data, Embeddings)
Plot_Recommendations((TopRecommendations, AvgSimilarities))
